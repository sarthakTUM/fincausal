# %%
import pandas as pd
import numpy as np
from pathlib import Path
import pickle
import os
import re
import collections
from typing import List, Tuple
from tqdm import tqdm
from nltk import word_tokenize

# %%
original_task2_filepath = Path('/media/sarthak/HDD/data_science/fnp_resources/data/task2/practice/fnp2020-fincausal2-task2.csv')
task2_original_df = pd.read_csv(original_task2_filepath, sep='; ', encoding='utf-8')
print('shape of data is: {}'.format(task2_original_df.shape))
task2_original_df.head()
# Out:
# /media/sarthak/HDD/Anaconda/envs/fnp/lib/python3.6/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# shape of data is: (1109, 11)
#           Index                                               Text  \
# 0  0001.00005.1  The Sunshine State drew in a net influx of abo...
# 1  0001.00005.2  The Sunshine State drew in a net influx of abo...
# 2    0001.00007  Florida is unique in that it also draws a larg...
# 3    0001.00009  Connecticut, Pennsylvania, New Jersey, Illinoi...
# 4    0001.00011  CLICK HERE TO GET THE FOX BUSINESS APP  Data f...
#
#                                                Cause  \
# 0  It is consistently one of the most popular des...
# 1  It is consistently one of the most popular des...
# 2  Florida is unique in that it also draws a larg...
# 3           the wealthy were picking up and leaving.
# 4  CLICK HERE TO GET THE FOX BUSINESS APP  Data f...
#
#                                               Effect  Offset_Sentence2  \
# 0  The Sunshine State drew in a net influx of abo...             159.0
# 1  Florida's $17.7 billion in net AGI dwarves the...             159.0
# 2  more than 85 percent of its net inflow of inco...               NaN
# 3  Connecticut, Pennsylvania, New Jersey, Illinoi...               NaN
# 4  New York's outflows to the Sunshine State were...               NaN
#
#    Offset_Sentence3  Cause_Start  Cause_End  Effect_Start  Effect_End  \
# 0             264.0          160        264             0         159
# 1             264.0          160        264           265         421
# 2               NaN            0         90            95         190
# 3               NaN          147        187             0         131
# 4               NaN            0        150           152         229
#
#                                             Sentence
# 0  <e2>The Sunshine State drew in a net influx of...
# 1  The Sunshine State drew in a net influx of abo...
# 2  <e1>Florida is unique in that it also draws a ...
# 3  <e2>Connecticut, Pennsylvania, New Jersey, Ill...
# 4  <e1>CLICK HERE TO GET THE FOX BUSINESS APP  Da...

# %%
class Tokenizer:
    
    def __init__(self):
        # self.nlp = English()
        # self.tokenizer = self.nlp.Defaults.create_tokenizer(nlp)
        self.tokenizer = word_tokenize
    
    def tokenize(self, string: str) -> List[Tuple[str, int]]:
        """
        given a continuous string, output a list of tuple where each tuple contains a tokena nd it's offset in 
        string
        """
        tokens = self.tokenizer(string)
        return [(token, None) for token in tokens]
tokenizer = Tokenizer()

# %%
def get_substring(string: str, offset_start: int, offset_end: int):
    """
    returns substring between offset_start (inclusive) and offset_end (inclusive)
    """
    if offset_end < offset_start:
        return ''
    else:
        # +1 becase it is inclusive and range subsetting excludes the last index
        return string[offset_start:offset_end+1]

# %%
def tag_iobes(list_of_labels: List[str]):
    label_string = list_of_labels[0]
    if len(list_of_labels) == 1:
        return ['S-'+label_string.upper()]
    else:
        tagged_labels = []
        for idx in range(len(list_of_labels)):
            if idx == 0:
                tagged_labels.append('B-'+label_string.upper())
            elif idx != 0 and idx < len(list_of_labels)-1:
                tagged_labels.append('I-'+label_string.upper())
            elif idx == len(list_of_labels)-1:
                tagged_labels.append('E-'+label_string.upper())
        assert len(list_of_labels) == len(tagged_labels)
        return tagged_labels

# %%
def convert_task2_data_to_list_of_tokens_with_labels(text: str, 
                                                     cause_offsets: Tuple[int, int],
                                                     effect_offsets: Tuple[int, int]):

    # 2. get all the offsets
    cause_first = cause_offsets < effect_offsets
    segment_before_offsets = (0, cause_offsets[0]-1) if cause_first else (0, effect_offsets[0]-1)
    segment_between_offsets = (cause_offsets[1]+1, effect_offsets[0]-1) if cause_first else (effect_offsets[1]+1, cause_offsets[0]-1)

    segment_after_offsets = (effect_offsets[1]+1, len(text)-1) if cause_first else (cause_offsets[1]+1, len(text)-1)

    # 3. create offset to label map
    offset_to_label_map = {
        cause_offsets:'C',
        effect_offsets:'E',
        segment_before_offsets:'B',
        segment_between_offsets:'M',
        segment_after_offsets:'A'
    }
    label_to_offset_map = {
        v:k for k,v in offset_to_label_map.items()
    }


    # 4. get the substrings between the offsets
    subset_string_cause = get_substring(string=text, 
                                        offset_start=label_to_offset_map['C'][0], 
                                        offset_end=label_to_offset_map['C'][1]).strip()
    subset_string_effect = get_substring(string=text, 
                                         offset_start=label_to_offset_map['E'][0], 
                                         offset_end=label_to_offset_map['E'][1]).strip()
    subset_string_before = get_substring(string=text, 
                                         offset_start=label_to_offset_map['B'][0], 
                                         offset_end=label_to_offset_map['B'][1]).strip()
    subset_string_after = get_substring(string=text, 
                                        offset_start=label_to_offset_map['A'][0], 
                                        offset_end=label_to_offset_map['A'][1]).strip()
    subset_string_between = get_substring(string=text, 
                                          offset_start=label_to_offset_map['M'][0], 
                                          offset_end=label_to_offset_map['M'][1]).strip()



    # 6. tokenize the substrings
    # tokenizer is declared outside
    offset_to_tokens_map = {
        cause_offsets: [tup[0] for tup in tokenizer.tokenize(subset_string_cause)],
        effect_offsets: [tup[0] for tup in tokenizer.tokenize(subset_string_effect)],
        segment_before_offsets: [tup[0] for tup in tokenizer.tokenize(subset_string_before)],
        segment_after_offsets: [tup[0] for tup in tokenizer.tokenize(subset_string_after)],
        segment_between_offsets: [tup[0] for tup in tokenizer.tokenize(subset_string_between)]
    }

    # 7. sort the offsets
    offsets_sorted = sorted(offset_to_label_map.keys())

    # 8. create the tokenized and labeled sentence
    text_tokenized_labeled = []
    for offsets in offsets_sorted:
        list_of_tokens = offset_to_tokens_map[offsets]
        list_of_labels = [offset_to_label_map[offsets]] * len(list_of_tokens)
        if list_of_tokens != []:
            list_of_labels = tag_iobes(list_of_labels)
            text_tokenized_labeled.extend([(token, label) for token, label in zip(list_of_tokens, list_of_labels)])

    return text_tokenized_labeled

# %%
# 1. get a text
sample_text = task2_original_df['Text'][0]
sample_cause = task2_original_df['Cause'][0]
sample_effect = task2_original_df['Effect'][0]
sample_cause_offsets = (task2_original_df['Cause_Start'][0], task2_original_df['Cause_End'][0])
sample_effect_offsets = (task2_original_df['Effect_Start'][0], task2_original_df['Effect_End'][0])

print('sample text: {}'.format(sample_text))
print('sample cause: {}'.format(sample_cause))
print('sample effect: {}'.format(sample_effect))
sample_text_tokenized_labeled = convert_task2_data_to_list_of_tokens_with_labels(text=sample_text,
                                                                                 cause_offsets=sample_cause_offsets,
                                                                                 effect_offsets=sample_effect_offsets)
print('okenized and labeled sentence: {}'.format(sample_text_tokenized_labeled))
# Out:
# sample text: The Sunshine State drew in a net influx of about $17.7 billion in adjusted gross income (AGI)  -  most of which (72 percent) came from those aged 55 and older. It is consistently one of the most popular destinations for retirees due to affordability and low taxes. Florida's $17.7 billion in net AGI dwarves the remaining 19 states that saw a positive net influx of income  -  which combined for a total of $19.4 billion.
# sample cause: It is consistently one of the most popular destinations for retirees due to affordability and low taxes.
# sample effect: The Sunshine State drew in a net influx of about $17.7 billion in adjusted gross income (AGI)  -  most of which (72 percent) came from those aged 55 and older.
# okenized and labeled sentence: [('The', 'B-E'), ('Sunshine', 'I-E'), ('State', 'I-E'), ('drew', 'I-E'), ('in', 'I-E'), ('a', 'I-E'), ('net', 'I-E'), ('influx', 'I-E'), ('of', 'I-E'), ('about', 'I-E'), ('$', 'I-E'), ('17.7', 'I-E'), ('billion', 'I-E'), ('in', 'I-E'), ('adjusted', 'I-E'), ('gross', 'I-E'), ('income', 'I-E'), ('(', 'I-E'), ('AGI', 'I-E'), (')', 'I-E'), ('-', 'I-E'), ('most', 'I-E'), ('of', 'I-E'), ('which', 'I-E'), ('(', 'I-E'), ('72', 'I-E'), ('percent', 'I-E'), (')', 'I-E'), ('came', 'I-E'), ('from', 'I-E'), ('those', 'I-E'), ('aged', 'I-E'), ('55', 'I-E'), ('and', 'I-E'), ('older', 'I-E'), ('.', 'E-E'), ('It', 'B-C'), ('is', 'I-C'), ('consistently', 'I-C'), ('one', 'I-C'), ('of', 'I-C'), ('the', 'I-C'), ('most', 'I-C'), ('popular', 'I-C'), ('destinations', 'I-C'), ('for', 'I-C'), ('retirees', 'I-C'), ('due', 'I-C'), ('to', 'I-C'), ('affordability', 'I-C'), ('and', 'I-C'), ('low', 'I-C'), ('taxes', 'I-C'), ('.', 'E-C'), ('Florida', 'B-A'), ("'s", 'I-A'), ('$', 'I-A'), ('17.7', 'I-A'), ('billion', 'I-A'), ('in', 'I-A'), ('net', 'I-A'), ('AGI', 'I-A'), ('dwarves', 'I-A'), ('the', 'I-A'), ('remaining', 'I-A'), ('19', 'I-A'), ('states', 'I-A'), ('that', 'I-A'), ('saw', 'I-A'), ('a', 'I-A'), ('positive', 'I-A'), ('net', 'I-A'), ('influx', 'I-A'), ('of', 'I-A'), ('income', 'I-A'), ('-', 'I-A'), ('which', 'I-A'), ('combined', 'I-A'), ('for', 'I-A'), ('a', 'I-A'), ('total', 'I-A'), ('of', 'I-A'), ('$', 'I-A'), ('19.4', 'I-A'), ('billion', 'I-A'), ('.', 'E-A')]

# %%
list_of_texts_tokenized_and_labeled = {}
for row_idx, row in tqdm(task2_original_df.iterrows()):
    list_of_texts_tokenized_and_labeled[row.Index] = convert_task2_data_to_list_of_tokens_with_labels(row['Text'],
                                                                                                (row['Cause_Start'], row['Cause_End']),
                                                                                                (row['Effect_Start'], row['Effect_End']))
# Out:
# 1109it [00:00, 1473.72it/s]

# %%
list_of_texts_tokenized_and_labeled
# Out:
# {'0001.00005.1': [('The', 'B-E'),
#   ('Sunshine', 'I-E'),
#   ('State', 'I-E'),
#   ('drew', 'I-E'),
#   ('in', 'I-E'),
#   ('a', 'I-E'),
#   ('net', 'I-E'),
#   ('influx', 'I-E'),
#   ('of', 'I-E'),
#   ('about', 'I-E'),
#   ('$', 'I-E'),
#   ('17.7', 'I-E'),
#   ('billion', 'I-E'),
#   ('in', 'I-E'),
#   ('adjusted', 'I-E'),
#   ('gross', 'I-E'),
#   ('income', 'I-E'),
#   ('(', 'I-E'),
#   ('AGI', 'I-E'),
#   (')', 'I-E'),
#   ('-', 'I-E'),
#   ('most', 'I-E'),
#   ('of', 'I-E'),
#   ('which', 'I-E'),
#   ('(', 'I-E'),
#   ('72', 'I-E'),
#   ('percent', 'I-E'),
#   (')', 'I-E'),
#   ('came', 'I-E'),
#   ('from', 'I-E'),
#   ('those', 'I-E'),
#   ('aged', 'I-E'),
#   ('55', 'I-E'),
#   ('and', 'I-E'),
#   ('older', 'I-E'),
#   ('.', 'E-E'),
#   ('It', 'B-C'),
#   ('is', 'I-C'),
#   ('consistently', 'I-C'),
#   ('one', 'I-C'),
#   ('of', 'I-C'),
#   ('the', 'I-C'),
#   ('most', 'I-C'),
#   ('popular', 'I-C'),
#   ('destinations', 'I-C'),
#   ('for', 'I-C'),
#   ('retirees', 'I-C'),
#   ('due', 'I-C'),
#   ('to', 'I-C'),
#   ('affordability', 'I-C'),
#   ('and', 'I-C'),
#   ('low', 'I-C'),
#   ('taxes', 'I-C'),
#   ('.', 'E-C'),
#   ('Florida', 'B-A'),
#   ("'s", 'I-A'),
#   ('$', 'I-A'),
#   ('17.7', 'I-A'),
#   ('billion', 'I-A'),
#   ('in', 'I-A'),
#   ('net', 'I-A'),
#   ('AGI', 'I-A'),
#   ('dwarves', 'I-A'),
#   ('the', 'I-A'),
#   ('remaining', 'I-A'),
#   ('19', 'I-A'),
#   ('states', 'I-A'),
#   ('that', 'I-A'),
#   ('saw', 'I-A'),
#   ('a', 'I-A'),
#   ('positive', 'I-A'),
#   ('net', 'I-A'),
#   ('influx', 'I-A'),
#   ('of', 'I-A'),
#   ('income', 'I-A'),
#   ('-', 'I-A'),
#   ('which', 'I-A'),
#   ('combined', 'I-A'),
#   ('for', 'I-A'),
#   ('a', 'I-A'),
#   ('total', 'I-A'),
#   ('of', 'I-A'),
#   ('$', 'I-A'),
#   ('19.4', 'I-A'),
#   ('billion', 'I-A'),
#   ('.', 'E-A')],
#  '0001.00005.2': [('The', 'B-B'),
#   ('Sunshine', 'I-B'),
#   ('State', 'I-B'),
#   ('drew', 'I-B'),
#   ('in', 'I-B'),
#   ('a', 'I-B'),
#   ('net', 'I-B'),
#   ('influx', 'I-B'),
#   ('of', 'I-B'),
#   ('about', 'I-B'),
#   ('$', 'I-B'),
#   ('17.7', 'I-B'),
#   ('billion', 'I-B'),
#   ('in', 'I-B'),
#   ('adjusted', 'I-B'),
#   ('gross', 'I-B'),
#   ('income', 'I-B'),
#   ('(', 'I-B'),
#   ('AGI', 'I-B'),
#   (')', 'I-B'),
#   ('-', 'I-B'),
#   ('most', 'I-B'),
#   ('of', 'I-B'),
#   ('which', 'I-B'),
#   ('(', 'I-B'),
#   ('72', 'I-B'),
#   ('percent', 'I-B'),
#   (')', 'I-B'),
#   ('came', 'I-B'),
#   ('from', 'I-B'),
#   ('those', 'I-B'),
#   ('aged', 'I-B'),
#   ('55', 'I-B'),
#   ('and', 'I-B'),
#   ('older', 'I-B'),
#   ('.', 'E-B'),
#   ('It', 'B-C'),
#   ('is', 'I-C'),
#   ('consistently', 'I-C'),
#   ('one', 'I-C'),
#   ('of', 'I-C'),
#   ('the', 'I-C'),
#   ('most', 'I-C'),
#   ('popular', 'I-C'),
#   ('destinations', 'I-C'),
#   ('for', 'I-C'),
#   ('retirees', 'I-C'),
#   ('due', 'I-C'),
#   ('to', 'I-C'),
#   ('affordability', 'I-C'),
#   ('and', 'I-C'),
#   ('low', 'I-C'),
#   ('taxes', 'I-C'),
#   ('.', 'E-C'),
#   ('Florida', 'B-E'),
#   ("'s", 'I-E'),
#   ('$', 'I-E'),
#   ('17.7', 'I-E'),
#   ('billion', 'I-E'),
#   ('in', 'I-E'),
#   ('net', 'I-E'),
#   ('AGI', 'I-E'),
#   ('dwarves', 'I-E'),
#   ('the', 'I-E'),
#   ('remaining', 'I-E'),
#   ('19', 'I-E'),
#   ('states', 'I-E'),
#   ('that', 'I-E'),
#   ('saw', 'I-E'),
#   ('a', 'I-E'),
#   ('positive', 'I-E'),
#   ('net', 'I-E'),
#   ('influx', 'I-E'),
#   ('of', 'I-E'),
#   ('income', 'I-E'),
#   ('-', 'I-E'),
#   ('which', 'I-E'),
#   ('combined', 'I-E'),
#   ('for', 'I-E'),
#   ('a', 'I-E'),
#   ('total', 'I-E'),
#   ('of', 'I-E'),
#   ('$', 'I-E'),
#   ('19.4', 'I-E'),
#   ('billion', 'I-E'),
#   ('.', 'E-E')],
#  '0001.00007': [('Florida', 'B-C'),
#   ('is', 'I-C'),
#   ('unique', 'I-C'),
#   ('in', 'I-C'),
#   ('that', 'I-C'),
#   ('it', 'I-C'),
#   ('also', 'I-C'),
#   ('draws', 'I-C'),
#   ('a', 'I-C'),
#   ('large', 'I-C'),
#   ('proportion', 'I-C'),
#   ('of', 'I-C'),
#   ('higher', 'I-C'),
#   ('net-worth', 'I-C'),
#   ('individuals', 'E-C'),
#   ('-', 'S-M'),
#   ('more', 'B-E'),
#   ('than', 'I-E'),
#   ('85', 'I-E'),
#   ('percent', 'I-E'),
#   ('of', 'I-E'),
#   ('its', 'I-E'),
#   ('net', 'I-E'),
#   ('inflow', 'I-E'),
#   ('of', 'I-E'),
#   ('income', 'I-E'),
#   ('came', 'I-E'),
#   ('from', 'I-E'),
#   ('people', 'I-E'),
#   ('earning', 'I-E'),
#   ('at', 'I-E'),
#   ('least', 'I-E'),
#   ('six-figures', 'I-E'),
#   ('.', 'E-E')],
#  '0001.00009': [('Connecticut', 'B-E'),
#   (',', 'I-E'),
#   ('Pennsylvania', 'I-E'),
#   (',', 'I-E'),
#   ('New', 'I-E'),
#   ('Jersey', 'I-E'),
#   (',', 'I-E'),
#   ('Illinois', 'I-E'),
#   ('and', 'I-E'),
#   ('New', 'I-E'),
#   ('York', 'I-E'),
#   ('lost', 'I-E'),
#   ('about', 'I-E'),
#   ('half', 'I-E'),
#   ('of', 'I-E'),
#   ('their', 'I-E'),
#   ('income', 'I-E'),
#   ('from', 'I-E'),
#   ('people', 'I-E'),
#   ('earning', 'I-E'),
#   ('more', 'I-E'),
#   ('than', 'I-E'),
#   ('$', 'I-E'),
#   ('200,000', 'E-E'),
#   ('-', 'B-M'),
#   ('indicating', 'E-M'),
#   ('the', 'B-C'),
#   ('wealthy', 'I-C'),
#   ('were', 'I-C'),
#   ('picking', 'I-C'),
#   ('up', 'I-C'),
#   ('and', 'I-C'),
#   ('leaving', 'I-C'),
#   ('.', 'E-C')],
#  '0001.00011': [('CLICK', 'B-C'),
#   ('HERE', 'I-C'),
#   ('TO', 'I-C'),
#   ('GET', 'I-C'),
#   ('THE', 'I-C'),
#   ('FOX', 'I-C'),
#   ('BUSINESS', 'I-C'),
#   ('APP', 'I-C'),
#   ('Data', 'I-C'),
#   ('from', 'I-C'),
#   ('the', 'I-C'),
#   ('U.S.', 'I-C'),
#   ('Census', 'I-C'),
#   ('Bureau', 'I-C'),
#   ('showed', 'I-C'),
#   ('that', 'I-C'),
#   ('while', 'I-C'),
#   ('Florida', 'I-C'),
#   ('received', 'I-C'),
#   ('more', 'I-C'),
#   ('movers', 'I-C'),
#   ('than', 'I-C'),
#   ('any', 'I-C'),
#   ('other', 'I-C'),
#   ('state', 'I-C'),
#   ('last', 'I-C'),
#   ('year', 'I-C'),
#   (',', 'E-C'),
#   ('New', 'B-E'),
#   ('York', 'I-E'),
#   ("'s", 'I-E'),
#   ('outflows', 'I-E'),
#   ('to', 'I-E'),
#   ('the', 'I-E'),
#   ('Sunshine', 'I-E'),
#   ('State', 'I-E'),
#   ('were', 'I-E'),
#   ('the', 'I-E'),
#   ('highest', 'I-E'),
#   ('-', 'I-E'),
#   ('63,772', 'I-E'),
#   ('people', 'I-E'),
#   ('.', 'E-E')],
#  '0001.00012': [('New', 'B-E'),
#   ('York', 'I-E'),
#   ('had', 'I-E'),
#   ('the', 'I-E'),
#   ('third-largest', 'I-E'),
#   ('outflows', 'I-E'),
#   ('of', 'I-E'),
#   ('any', 'I-E'),
#   ('state', 'I-E'),
#   (',', 'I-E'),
#   ('with', 'I-E'),
#   ('452,580', 'I-E'),
#   ('people', 'I-E'),
#   ('moving', 'I-E'),
#   ('out', 'I-E'),
#   ('within', 'I-E'),
#   ('the', 'I-E'),
#   ('past', 'I-E'),
#   ('year', 'I-E'),
#   ('.', 'E-E'),
#   ('Individuals', 'B-C'),
#   ('earning', 'I-C'),
#   ('$', 'I-C'),
#   ('650,000', 'I-C'),
#   ('can', 'I-C'),
#   ('save', 'I-C'),
#   ('more', 'I-C'),
#   ('than', 'I-C'),
#   ('$', 'I-C'),
#   ('69,700', 'I-C'),
#   ('in', 'I-C'),
#   ('taxes', 'I-C'),
#   ('per', 'I-C'),
#   ('year', 'I-C'),
#   ('by', 'I-C'),
#   ('moving', 'I-C'),
#   ('from', 'I-C'),
#   ('New', 'I-C'),
#   ('York', 'I-C'),
#   ('to', 'I-C'),
#   ('Florida', 'I-C'),
#   ('.', 'E-C')],
#  '0003.00004': [('The', 'B-C'),
#   ('stock', 'I-C'),
#   ('increased', 'I-C'),
#   ('1.02', 'I-C'),
#   ('%', 'I-C'),
#   ('or', 'I-C'),
#   ('$', 'I-C'),
#   ('0.23', 'I-C'),
#   ('during', 'I-C'),
#   ('the', 'I-C'),
#   ('last', 'I-C'),
#   ('trading', 'I-C'),
#   ('session', 'I-C'),
#   (',', 'E-C'),
#   ('reaching', 'B-E'),
#   ('$', 'I-E'),
#   ('22.69', 'I-E'),
#   ('.', 'E-E')],
#  '0003.00006': [('(', 'B-E'),
#   ('NASDAQ', 'I-E'),
#   (':', 'I-E'),
#   ('SBRA', 'I-E'),
#   (')', 'I-E'),
#   ('has', 'I-E'),
#   ('declined', 'I-E'),
#   ('1.62', 'I-E'),
#   ('%', 'I-E'),
#   ('since', 'I-E'),
#   ('September', 'I-E'),
#   ('21', 'I-E'),
#   (',', 'I-E'),
#   ('2018', 'I-E'),
#   ('and', 'I-E'),
#   ('is', 'I-E'),
#   ('downtrending', 'I-E'),
#   ('.', 'E-E'),
#   ('It', 'B-C'),
#   ('has', 'I-C'),
#   ('underperformed', 'I-C'),
#   ('by', 'I-C'),
#   ('1.62', 'I-C'),
#   ('%', 'I-C'),
#   ('the', 'I-C'),
#   ('S', 'I-C'),
#   ('&', 'I-C'),
#   ('P500', 'I-C'),
#   ('.', 'E-C')],
#  '0003.00008': [('The', 'B-C'),
#   ('stock', 'I-C'),
#   ('decreased', 'I-C'),
#   ('0.54', 'I-C'),
#   ('%', 'I-C'),
#   ('or', 'I-C'),
#   ('$', 'I-C'),
#   ('0.15', 'I-C'),
#   ('during', 'I-C'),
#   ('the', 'I-C'),
#   ('last', 'I-C'),
#   ('trading', 'I-C'),
#   ('session', 'I-C'),
#   (',', 'E-C'),
#   ('reaching', 'B-E'),
#   ('$', 'I-E'),
#   ('27.64', 'I-E'),
#   ('.', 'E-E')],
#  '0003.00010': [('Weyerhaeuser', 'B-E'),
#   ('Company', 'I-E'),
#   ('(', 'I-E'),
#   ('NYSE', 'I-E'),
#   (':', 'I-E'),
#   ('WY', 'I-E'),
#   (')', 'I-E'),
#   ('has', 'I-E'),
#   ('declined', 'I-E'),
#   ('25.53', 'I-E'),
#   ('%', 'I-E'),
#   ('since', 'I-E'),
#   ('September', 'I-E'),
#   ('21', 'I-E'),
#   (',', 'I-E'),
#   ('2018', 'I-E'),
#   ('and', 'I-E'),
#   ('is', 'I-E'),
#   ('downtrending', 'I-E'),
#   ('.', 'E-E'),
#   ('It', 'B-C'),
#   ('has', 'I-C'),
#   ('underperformed', 'I-C'),
#   ('by', 'I-C'),
#   ('25.53', 'I-C'),
#   ('%', 'I-C'),
#   ('the', 'I-C'),
#   ('S', 'I-C'),
#   ('&', 'I-C'),
#   ('P500', 'I-C'),
#   ('.', 'E-C')],
#  '0003.00015': [('After', 'B-C'),
#   ('$', 'I-C'),
#   ('0.46', 'I-C'),
#   ('actual', 'I-C'),
#   ('EPS', 'I-C'),
#   ('reported', 'I-C'),
#   ('by', 'I-C'),
#   ('Sabra', 'I-C'),
#   ('Health', 'I-C'),
#   ('Care', 'I-C'),
#   ('REIT', 'I-C'),
#   (',', 'I-C'),
#   ('Inc.', 'I-C'),
#   ('for', 'I-C'),
#   ('the', 'I-C'),
#   ('previous', 'I-C'),
#   ('quarter', 'I-C'),
#   (',', 'E-C'),
#   ('Wall', 'B-E'),
#   ('Street', 'I-E'),
#   ('now', 'I-E'),
#   ('forecasts', 'I-E'),
#   ('2.17', 'I-E'),
#   ('%', 'I-E'),
#   ('EPS', 'I-E'),
#   ('growth', 'I-E'),
#   ('.', 'E-E')],
#  '0003.00016': [('Investors', 'B-C'),
#   ('sentiment', 'I-C'),
#   ('increased', 'I-C'),
#   ('to', 'I-C'),
#   ('1.25', 'I-C'),
#   ('in', 'I-C'),
#   ('Q2', 'I-C'),
#   ('2019', 'I-C'),
#   ('.', 'E-C'),
#   ('Its', 'B-M'),
#   ('up', 'I-M'),
#   ('0.38', 'I-M'),
#   (',', 'I-M'),
#   ('from', 'I-M'),
#   ('0.87', 'I-M'),
#   ('in', 'I-M'),
#   ('2019Q1', 'I-M'),
#   ('.', 'E-M'),
#   ('It', 'B-E'),
#   ('increased', 'I-E'),
#   (',', 'I-E'),
#   ('as', 'I-E'),
#   ('23', 'I-E'),
#   ('investors', 'I-E'),
#   ('sold', 'I-E'),
#   ('SBRA', 'I-E'),
#   ('shares', 'I-E'),
#   ('while', 'I-E'),
#   ('68', 'I-E'),
#   ('reduced', 'I-E'),
#   ('holdings', 'I-E'),
#   ('.', 'E-E')],
#  '0003.00039': [('Investors', 'B-C'),
#   ('sentiment', 'I-C'),
#   ('decreased', 'I-C'),
#   ('to', 'I-C'),
#   ('1.02', 'I-C'),
#   ('in', 'I-C'),
#   ('2019', 'I-C'),
#   ('Q2', 'I-C'),
#   ('.', 'E-C'),
#   ('Its', 'B-M'),
#   ('down', 'I-M'),
#   ('0.11', 'I-M'),
#   (',', 'I-M'),
#   ('from', 'I-M'),
#   ('1.13', 'I-M'),
#   ('in', 'I-M'),
#   ('2019Q1', 'I-M'),
#   ('.', 'E-M'),
#   ('It', 'B-E'),
#   ('worsened', 'I-E'),
#   (',', 'I-E'),
#   ('as', 'I-E'),
#   ('43', 'I-E'),
#   ('investors', 'I-E'),
#   ('sold', 'I-E'),
#   ('WY', 'I-E'),
#   ('shares', 'I-E'),
#   ('while', 'I-E'),
#   ('242', 'I-E'),
#   ('reduced', 'I-E'),
#   ('holdings', 'I-E'),
#   ('.', 'E-E')],
#  '0004.00001': [('Thomas', 'B-E'),
#   ('Cook', 'I-E'),
#   ('Thomas', 'I-E'),
#   ('Cook', 'I-E'),
#   ('collapses', 'I-E'),
#   (',', 'I-E'),
#   ('stranding', 'I-E'),
#   ('150,000', 'I-E'),
#   ('UK', 'I-E'),
#   ('holidaymakers', 'I-E'),
#   ('About', 'I-E'),
#   ('9,000', 'I-E'),
#   ('British', 'I-E'),
#   ('jobs', 'I-E'),
#   ('at', 'I-E'),
#   ('risk', 'I-E'),
#   ('after', 'I-E'),
#   ('last-minute', 'I-E'),
#   ('rescue', 'I-E'),
#   ('talks', 'I-E'),
#   ('fail', 'I-E'),
#   ('to', 'I-E'),
#   ('keep', 'I-E'),
#   ('firm', 'I-E'),
#   ('afloat', 'E-E'),
#   ('Simon', 'B-C'),
#   ('Goodley', 'I-C'),
#   (',', 'I-C'),
#   ('Kalyeena', 'I-C'),
#   ('Makortoff', 'I-C'),
#   ('and', 'I-C'),
#   ('Caroline', 'I-C'),
#   ('Bannock', 'I-C'),
#   ('Thomas', 'I-C'),
#   ('Cook', 'I-C'),
#   ('bosses', 'I-C'),
#   ('held', 'I-C'),
#   ('talks', 'I-C'),
#   ('on', 'I-C'),
#   ('Sunday', 'I-C'),
#   ('to', 'I-C'),
#   ('avert', 'I-C'),
#   ('administration', 'I-C'),
#   ('but', 'I-C'),
#   ('it', 'I-C'),
#   ('was', 'I-C'),
#   ('declared', 'I-C'),
#   ('bust', 'I-C'),
#   ('at', 'I-C'),
#   ('2am', 'I-C'),
#   ('.', 'E-C')],
#  '0004.00002': [('Photograph', 'B-C'),
#   (':', 'I-C'),
#   ('Christopher', 'I-C'),
#   ('Thomond/The', 'I-C'),
#   ('Guardian', 'I-C'),
#   ('Thomas', 'I-C'),
#   ('Cook', 'I-C'),
#   ('has', 'I-C'),
#   ('ceased', 'I-C'),
#   ('trading', 'I-C'),
#   ('after', 'I-C'),
#   ('talks', 'I-C'),
#   ('failed', 'I-C'),
#   ('to', 'I-C'),
#   ('produce', 'I-C'),
#   ('a', 'I-C'),
#   ('funding', 'I-C'),
#   ('lifeline', 'I-C'),
#   ('for', 'I-C'),
#   ('the', 'I-C'),
#   ('ailing', 'I-C'),
#   ('travel', 'I-C'),
#   ('company', 'I-C'),
#   (',', 'E-C'),
#   ('placing', 'B-E'),
#   ('9,000', 'I-E'),
#   ('British', 'I-E'),
#   ('jobs', 'I-E'),
#   ('at', 'I-E'),
#   ('risk', 'I-E'),
#   ('and', 'I-E'),
#   ('triggering', 'I-E'),
#   ('a', 'I-E'),
#   ('huge', 'I-E'),
#   ('repatriation', 'I-E'),
#   ('effort', 'I-E'),
#   ('to', 'I-E'),
#   ('bring', 'I-E'),
#   ('home', 'I-E'),
#   ('150,000', 'I-E'),
#   ('UK', 'I-E'),
#   ('holidaymakers', 'I-E'),
#   ('overseas', 'I-E'),
#   ('.', 'E-E')],
#  '0004.00017': [('The', 'B-E'),
#   ('total', 'I-E'),
#   ('cost', 'I-E'),
#   ('of', 'I-E'),
#   ('holidaymakers', 'I-E'),
#   ("'", 'I-E'),
#   ('guarantees', 'I-E'),
#   ('to', 'I-E'),
#   ('be', 'I-E'),
#   ('paid', 'I-E'),
#   ('by', 'I-E'),
#   ('the', 'I-E'),
#   ('Atol', 'I-E'),
#   ('scheme', 'I-E'),
#   ('-', 'I-E'),
#   ('underwritten', 'I-E'),
#   ('by', 'I-E'),
#   ('the', 'I-E'),
#   ('Civil', 'I-E'),
#   ('Aviation', 'I-E'),
#   ('Authority', 'I-E'),
#   ('watchdog', 'I-E'),
#   ('-', 'I-E'),
#   ('is', 'I-E'),
#   ('an', 'I-E'),
#   ('estimated', 'I-E'),
#   ('£600m', 'E-E'),
#   ('now', 'B-M'),
#   ('that', 'E-M'),
#   ('the', 'B-C'),
#   ('company', 'I-C'),
#   ('has', 'I-C'),
#   ('gone', 'I-C'),
#   ('bust', 'I-C'),
#   ('.', 'E-C')],
#  '0004.00021': [('Addressing', 'B-C'),
#   ('the', 'I-C'),
#   ('temperance', 'I-C'),
#   ('meeting', 'I-C'),
#   (',', 'I-C'),
#   ('he', 'I-C'),
#   ('suggested', 'I-C'),
#   ('that', 'I-C'),
#   ('a', 'I-C'),
#   ('train', 'I-C'),
#   ('be', 'I-C'),
#   ('hired', 'I-C'),
#   ('to', 'I-C'),
#   ('carry', 'I-C'),
#   ('the', 'I-C'),
#   ('movement', 'I-C'),
#   ("'s", 'I-C'),
#   ('supporters', 'I-C'),
#   ('to', 'I-C'),
#   ('the', 'I-C'),
#   ('next', 'I-C'),
#   ('meeting', 'I-C'),
#   ('in', 'I-C'),
#   ('Loughborough', 'I-C'),
#   ('.', 'E-C'),
#   ('Thus', 'B-E'),
#   (',', 'I-E'),
#   ('on', 'I-E'),
#   ('5', 'I-E'),
#   ('July', 'I-E'),
#   ('1841', 'I-E'),
#   (',', 'I-E'),
#   ('some', 'I-E'),
#   ('500', 'I-E'),
#   ('passengers', 'I-E'),
#   ('travelled', 'I-E'),
#   ('by', 'I-E'),
#   ('a', 'I-E'),
#   ('special', 'I-E'),
#   ('train', 'I-E'),
#   ('for', 'I-E'),
#   ('the', 'I-E'),
#   ('24-mile', 'I-E'),
#   ('round', 'I-E'),
#   ('trip', 'I-E'),
#   (',', 'I-E'),
#   ('paying', 'I-E'),
#   ('a', 'I-E'),
#   ('shilling', 'I-E'),
#   ('apiece', 'I-E'),
#   ('.', 'E-E')],
#  '0004.00042': [('After', 'B-C'),
#   ('the', 'I-C'),
#   ('war', 'I-C'),
#   (',', 'I-C'),
#   ('sales', 'I-C'),
#   ('took', 'I-C'),
#   ('off', 'I-C'),
#   ('again', 'I-C'),
#   ('with', 'I-C'),
#   ('the', 'I-C'),
#   ('era', 'I-C'),
#   ('of', 'I-C'),
#   ('package', 'I-C'),
#   ('holidays', 'I-C'),
#   ('.', 'E-C'),
#   ('By', 'B-E'),
#   ('1950', 'I-E'),
#   (',', 'I-E'),
#   ('more', 'I-E'),
#   ('than', 'I-E'),
#   ('a', 'I-E'),
#   ('million', 'I-E'),
#   ('Britons', 'I-E'),
#   ('were', 'I-E'),
#   ('travelling', 'I-E'),
#   ('abroad', 'I-E'),
#   ('each', 'I-E'),
#   ('year', 'I-E'),
#   (',', 'I-E'),
#   ('mainly', 'I-E'),
#   ('to', 'I-E'),
#   ('France', 'I-E'),
#   (',', 'I-E'),
#   ('Italy', 'I-E'),
#   (',', 'I-E'),
#   ('Spain', 'I-E'),
#   ('and', 'I-E'),
#   ('Switzerland', 'I-E'),
#   ('.', 'E-E')],
#  '0004.00044': [('In', 'B-C'),
#   ('2007', 'I-C'),
#   (',', 'I-C'),
#   ('it', 'I-C'),
#   ('merged', 'I-C'),
#   ('with', 'I-C'),
#   ('the', 'I-C'),
#   ('UK-listed', 'I-C'),
#   ('owner', 'I-C'),
#   ('of', 'I-C'),
#   ('Airtours', 'I-C'),
#   (',', 'I-C'),
#   ('MyTravel', 'I-C'),
#   ('Group', 'I-C'),
#   (',', 'I-C'),
#   ('which', 'I-C'),
#   ('nearly', 'I-C'),
#   ('collapsed', 'I-C'),
#   ('in', 'I-C'),
#   ('2011', 'I-C'),
#   ('but', 'I-C'),
#   ('was', 'I-C'),
#   ('bailed', 'I-C'),
#   ('out', 'I-C'),
#   ('by', 'I-C'),
#   ('its', 'I-C'),
#   ('banks', 'I-C'),
#   ('.', 'E-C'),
#   ('The', 'B-E'),
#   ('rescue', 'I-E'),
#   ('left', 'I-E'),
#   ('Thomas', 'I-E'),
#   ('Cook', 'I-E'),
#   ('with', 'I-E'),
#   ('a', 'I-E'),
#   ('debt', 'I-E'),
#   ('burden', 'I-E'),
#   ('of', 'I-E'),
#   ('£1.7bn', 'I-E'),
#   ('and', 'I-E'),
#   ('the', 'I-E'),
#   ('company', 'I-E'),
#   ('struggled', 'I-E'),
#   ('to', 'I-E'),
#   ('cope', 'I-E'),
#   (',', 'I-E'),
#   ('leaving', 'I-E'),
#   ('administration', 'I-E'),
#   ('as', 'I-E'),
#   ('the', 'I-E'),
#   ('only', 'I-E'),
#   ('option', 'I-E'),
#   ('.', 'E-E')],
#  '0005.00001': [('iShares', 'B-C'),
#   ('US', 'I-C'),
#   ('Preferred', 'I-C'),
#   ('Stock', 'I-C'),
#   ('ETF', 'I-C'),
#   ('(', 'I-C'),
#   ('NASDAQ', 'I-C'),
#   (':', 'I-C'),
#   ('PFF', 'I-C'),
#   (')', 'I-C'),
#   ('Shares', 'I-C'),
#   ('Bought', 'I-C'),
#   ('by', 'I-C'),
#   ('Security', 'I-C'),
#   ('National', 'I-C'),
#   ('Bank', 'I-C'),
#   ('of', 'I-C'),
#   ('Sioux', 'I-C'),
#   ('City', 'I-C'),
#   ('Iowa', 'I-C'),
#   ('IA', 'I-C'),
#   ('.3', 'I-C'),
#   ('%', 'I-C'),
#   ('during', 'I-C'),
#   ('the', 'I-C'),
#   ('2nd', 'I-C'),
#   ('quarter', 'I-C'),
#   (',', 'I-C'),
#   ('according', 'I-C'),
#   ('to', 'I-C'),
#   ('the', 'I-C'),
#   ('company', 'I-C'),
#   ('in', 'I-C'),
#   ('its', 'I-C'),
#   ('most', 'I-C'),
#   ('recent', 'I-C'),
#   ('13F', 'I-C'),
#   ('filing', 'I-C'),
#   ('with', 'I-C'),
#   ('the', 'I-C'),
#   ('Securities', 'I-C'),
#   ('and', 'I-C'),
#   ('Exchange', 'I-C'),
#   ('Commission', 'I-C'),
#   ('.', 'E-C'),
#   ('The', 'B-E'),
#   ('firm', 'I-E'),
#   ('owned', 'I-E'),
#   ('17,714', 'I-E'),
#   ('shares', 'I-E'),
#   ('of', 'I-E'),
#   ('the', 'I-E'),
#   ('company', 'I-E'),
#   ("'s", 'I-E'),
#   ('stock', 'I-E'),
#   ('after', 'I-E'),
#   ('buying', 'I-E'),
#   ('an', 'I-E'),
#   ('additional', 'I-E'),
#   ('1,355', 'I-E'),
#   ('shares', 'I-E'),
#   ('during', 'I-E'),
#   ('the', 'I-E'),
#   ('quarter', 'I-E'),
#   ('.', 'E-E')],
#  '0005.00003': [('Laurel', 'B-C'),
#   ('Wealth', 'I-C'),
#   ('Advisors', 'I-C'),
#   ('LLC', 'I-C'),
#   ('increased', 'I-C'),
#   ('its', 'I-C'),
#   ('holdings', 'I-C'),
#   ('in', 'I-C'),
#   ('iShares', 'I-C'),
#   ('US', 'I-C'),
#   ('Preferred', 'I-C'),
#   ('Stock', 'I-C'),
#   ('ETF', 'I-C'),
#   ('by', 'I-C'),
#   ('75.0', 'I-C'),
#   ('%', 'I-C'),
#   ('in', 'I-C'),
#   ('the', 'I-C'),
#   ('1st', 'I-C'),
#   ('quarter', 'I-C'),
#   ('.', 'E-C'),
#   ('Laurel', 'B-E'),
#   ('Wealth', 'I-E'),
#   ('Advisors', 'I-E'),
#   ('LLC', 'I-E'),
#   ('now', 'I-E'),
#   ('owns', 'I-E'),
#   ('700', 'I-E'),
#   ('shares', 'I-E'),
#   ('of', 'I-E'),
#   ('the', 'I-E'),
#   ('company', 'I-E'),
#   ("'s", 'I-E'),
#   ('stock', 'I-E'),
#   ('worth', 'I-E'),
#   ('$', 'I-E'),
#   ('26,000', 'I-E'),
#   ('after', 'I-E'),
#   ('buying', 'I-E'),
#   ('an', 'I-E'),
#   ('additional', 'I-E'),
#   ('300', 'I-E'),
#   ('shares', 'I-E'),
#   ('during', 'I-E'),
#   ('the', 'I-E'),
#   ('period', 'I-E'),
#   ('.', 'E-E')],
#  '0005.00007': [('Finally', 'B-C'),
#   (',', 'I-C'),
#   ('First', 'I-C'),
#   ('PREMIER', 'I-C'),
#   ('Bank', 'I-C'),
#   ('increased', 'I-C'),
#   ('its', 'I-C'),
#   ('holdings', 'I-C'),
#   ('in', 'I-C'),
#   ('iShares', 'I-C'),
#   ('US', 'I-C'),
#   ('Preferred', 'I-C'),
#   ('Stock', 'I-C'),
#   ('ETF', 'I-C'),
#   ('by', 'I-C'),
#   ('175.2', 'I-C'),
#   ('%', 'I-C'),
#   ('in', 'I-C'),
#   ('the', 'I-C'),
#   ('2nd', 'I-C'),
#   ('quarter', 'I-C'),
#   ('.', 'E-C'),
#   ('First', 'B-E'),
#   ('PREMIER', 'I-E'),
#   ('Bank', 'I-E'),
#   ('now', 'I-E'),
#   ('owns', 'I-E'),
#   ('1,365', 'I-E'),
#   ('shares', 'I-E'),
#   ('of', 'I-E'),
#   ('the', 'I-E'),
#   ('company', 'I-E'),
#   ("'s", 'I-E'),
#   ('stock', 'I-E'),
#   ('worth', 'I-E'),
#   ('$', 'I-E'),
#   ('50,000', 'I-E'),
#   ('after', 'I-E'),
#   ('buying', 'I-E'),
#   ('an', 'I-E'),
#   ('additional', 'I-E'),
#   ('869', 'I-E'),
#   ('shares', 'I-E'),
#   ('during', 'I-E'),
#   ('the', 'I-E'),
#   ('period', 'I-E'),
#   ('.', 'E-E')],
#  '0005.00008': [('NASDAQ', 'B-C'),
#   (':', 'I-C'),
#   ('PFF', 'I-C'),
#   ('traded', 'I-C'),
#   ('up', 'I-C'),
#   ('$', 'I-C'),
#   ('0.10', 'I-C'),
#   ('during', 'I-C'),
#   ('midday', 'I-C'),
#   ('trading', 'I-C'),
#   ('on', 'I-C'),
#   ('Monday', 'I-C'),
#   (',', 'E-C'),
#   ('hitting', 'B-E'),
#   ('$', 'I-E'),
#   ('37.51', 'I-E'),
#   ('.', 'E-E')],
#  '0006.00007': [('He', 'B-C'),
#   ('said', 'I-C'),
#   ('the', 'I-C'),
#   ('company', 'I-C'),
#   ('is', 'I-C'),
#   ('well', 'I-C'),
#   ('on', 'I-C'),
#   ('track', 'I-C'),
#   ('on', 'I-C'),
#   ('attaining', 'I-C'),
#   ('the', 'I-C'),
#   ('Final', 'I-C'),
#   ('Investment', 'I-C'),
#   ('Decision', 'I-C'),
#   ('(', 'I-C'),
#   ('FID', 'I-C'),
#   (')', 'I-C'),
#   ('on', 'I-C'),
#   ('Train', 'I-C'),
#   ('7', 'I-C'),
#   (',', 'E-C'),
#   ('which', 'B-M'),
#   ('would', 'I-M'),
#   ('see', 'E-M'),
#   ('its', 'B-E'),
#   ('production', 'I-E'),
#   ('rise', 'I-E'),
#   ('from', 'I-E'),
#   ('22mtpa', 'I-E'),
#   ('to', 'I-E'),
#   ('30mtpa', 'I-E'),
#   ('.', 'E-E')],
#  '0007.00001.1': [('iShares', 'B-C'),
#   ('S', 'I-C'),
#   ('&', 'I-C'),
#   ('P', 'I-C'),
#   ('Mid-Cap', 'I-C'),
#   ('400', 'I-C'),
#   ('Value', 'I-C'),
#   ('ETF', 'I-C'),
#   ('(', 'I-C'),
#   ('NYSEARCA', 'I-C'),
#   (':', 'I-C'),
#   ('IJJ', 'I-C'),
#   (')', 'I-C'),
#   ('declared', 'I-C'),
#   ('a', 'I-C'),
#   ('-', 'I-C'),
#   ('dividend', 'I-C'),
#   ('on', 'I-C'),
#   ('Tuesday', 'I-C'),
#   (',', 'I-C'),
#   ('September', 'I-C'),
#   ('24th', 'I-C'),
#   (',', 'I-C'),
#   ('Wall', 'I-C'),
#   ('Street', 'I-C'),
#   ('Journal', 'I-C'),
#   ('reports', 'I-C'),
#   ('.', 'E-C'),
#   ('Shareholders', 'B-E'),
#   ('of', 'I-E'),
#   ('record', 'I-E'),
#   ('on', 'I-E'),
#   ('Wednesday', 'I-E'),
#   (',', 'I-E'),
#   ('September', 'I-E'),
#   ('25th', 'I-E'),
#   ('will', 'I-E'),
#   ('be', 'I-E'),
#   ('given', 'I-E'),
#   ('a', 'I-E'),
#   ('dividend', 'I-E'),
#   ('of', 'I-E'),
#   ('0.7434', 'I-E'),
#   ('per', 'I-E'),
#   ('share', 'I-E'),
#   ('on', 'I-E'),
#   ('Monday', 'I-E'),
#   (',', 'I-E'),
#   ('September', 'I-E'),
#   ('30th', 'I-E'),
#   ('.', 'E-E'),
#   ('This', 'B-A'),
#   ('represents', 'I-A'),
#   ('a', 'I-A'),
#   ('yield', 'I-A'),
#   ('of', 'I-A'),
#   ('1.7', 'I-A'),
#   ('%', 'I-A'),
#   ('.', 'E-A')],
#  '0007.00001.2': [('iShares', 'B-C'),
#   ('S', 'I-C'),
#   ('&', 'I-C'),
#   ('P', 'I-C'),
#   ('Mid-Cap', 'I-C'),
#   ('400', 'I-C'),
#   ('Value', 'I-C'),
#   ('ETF', 'I-C'),
#   ('(', 'I-C'),
#   ('NYSEARCA', 'I-C'),
#   (':', 'I-C'),
#   ('IJJ', 'I-C'),
#   (')', 'I-C'),
#   ('declared', 'I-C'),
#   ('a', 'I-C'),
#   ('-', 'I-C'),
#   ('dividend', 'I-C'),
#   ('on', 'I-C'),
#   ('Tuesday', 'I-C'),
#   (',', 'I-C'),
#   ('September', 'I-C'),
#   ('24th', 'I-C'),
#   (',', 'I-C'),
#   ('Wall', 'I-C'),
#   ('Street', 'I-C'),
#   ('Journal', 'I-C'),
#   ('reports', 'I-C'),
#   ('.', 'E-C'),
#   ('Shareholders', 'B-M'),
#   ('of', 'I-M'),
#   ('record', 'I-M'),
#   ('on', 'I-M'),
#   ('Wednesday', 'I-M'),
#   (',', 'I-M'),
#   ('September', 'I-M'),
#   ('25th', 'I-M'),
#   ('will', 'I-M'),
#   ('be', 'I-M'),
#   ('given', 'I-M'),
#   ('a', 'I-M'),
#   ('dividend', 'I-M'),
#   ('of', 'I-M'),
#   ('0.7434', 'I-M'),
#   ('per', 'I-M'),
#   ('share', 'I-M'),
#   ('on', 'I-M'),
#   ('Monday', 'I-M'),
#   (',', 'I-M'),
#   ('September', 'I-M'),
#   ('30th', 'I-M'),
#   ('.', 'E-M'),
#   ('This', 'B-E'),
#   ('represents', 'I-E'),
#   ('a', 'I-E'),
#   ('yield', 'I-E'),
#   ('of', 'I-E'),
#   ('1.7', 'I-E'),
#   ('%', 'I-E'),
#   ('.', 'E-E')],
#  '0007.00003': [('IJJ', 'B-C'),
#   ('traded', 'I-C'),
#   ('down', 'I-C'),
#   ('$', 'I-C'),
#   ('2.57', 'I-C'),
#   ('during', 'I-C'),
#   ('trading', 'I-C'),
#   ('on', 'I-C'),
#   ('Tuesday', 'I-C'),
#   (',', 'E-C'),
#   ('hitting', 'B-E'),
#   ('$', 'I-E'),
#   ('158.26', 'I-E'),
#   ('.', 'E-E'),
#   ('89,200', 'B-A'),
#   ('shares', 'I-A'),
#   ('of', 'I-A'),
#   ('the', 'I-A'),
#   ('company', 'I-A'),
#   ("'s", 'I-A'),
#   ('stock', 'I-A'),
#   ('were', 'I-A'),
#   ('exchanged', 'I-A'),
#   (',', 'I-A'),
#   ('compared', 'I-A'),
#   ('to', 'I-A'),
#   ('its', 'I-A'),
#   ('average', 'I-A'),
#   ('volume', 'I-A'),
#   ('of', 'I-A'),
#   ('108,052', 'I-A'),
#   ('.', 'E-A')],
#  '0008.00001': [('President', 'B-E'),
#   ('Muhammadu', 'I-E'),
#   ('Buhari', 'I-E'),
#   ('has', 'I-E'),
#   ('disclosed', 'I-E'),
#   ('that', 'I-E'),
#   ('Nigeria', 'I-E'),
#   ('lost', 'I-E'),
#   ('an', 'I-E'),
#   ('estimated', 'I-E'),
#   ('$', 'I-E'),
#   ('157.5', 'I-E'),
#   ('billion', 'E-E'),
#   ('to', 'S-M'),
#   ('illicit', 'B-C'),
#   ('financial', 'I-C'),
#   ('flows', 'I-C'),
#   ('between', 'I-C'),
#   ('2003', 'I-C'),
#   ('and', 'I-C'),
#   ('2012', 'I-C'),
#   ('.', 'E-C'),
#   ('Mr', 'B-A'),
#   ('Buhari', 'I-A'),
#   ('quoted', 'I-A'),
#   ('from', 'I-A'),
#   ('the', 'I-A'),
#   ('2014', 'I-A'),
#   ('Global', 'I-A'),
#   ('Financial', 'I-A'),
#   ('Integrity', 'I-A'),
#   ('Report', 'I-A'),
#   ('in', 'I-A'),
#   ('his', 'I-A'),
#   ('address', 'I-A'),
#   ('to', 'I-A'),
#   ('the', 'I-A'),
#   ('High-Level', 'I-A'),
#   ('National', 'I-A'),
#   ('Side-Event', 'I-A'),
#   ('organised', 'I-A'),
#   ('by', 'I-A'),
#   ('the', 'I-A'),
#   ('African', 'I-A'),
#   ('Union', 'I-A'),
#   ('Development', 'I-A'),
#   ('Agency', 'I-A'),
#   ('and', 'I-A'),
#   ('New', 'I-A'),
#   ('Partnership', 'I-A'),
#   ('for', 'I-A'),
#   ('Africa', 'I-A'),
#   ("'s", 'I-A'),
#   ('Development', 'I-A'),
#   ('(', 'I-A'),
#   ('AUDA-NEPAD', 'I-A'),
#   (')', 'I-A'),
#   ('and', 'I-A'),
#   ('the', 'I-A'),
#   ('Economic', 'I-A'),
#   ('and', 'I-A'),
#   ('Financial', 'I-A'),
#   ('Crimes', 'I-A'),
#   ('Commission', 'I-A'),
#   ('(', 'I-A'),
#   ('EFCC', 'I-A'),
#   (')', 'I-A'),
#   ('.', 'E-A')],
#  '0008.00008': [('Citing', 'B-E'),
#   ('tax', 'I-E'),
#   ('avoidance', 'I-E'),
#   ('as', 'I-E'),
#   ('another', 'I-E'),
#   ('form', 'I-E'),
#   ('of', 'I-E'),
#   ('illicit', 'I-E'),
#   ('financial', 'I-E'),
#   ('flow', 'I-E'),
#   (',', 'I-E'),
#   ('he', 'I-E'),
#   ('quoted', 'I-E'),
#   ('the', 'I-E'),
#   ('Tax', 'I-E'),
#   ('Justice', 'I-E'),
#   ('Network', 'I-E'),
#   ('and', 'I-E'),
#   ('the', 'I-E'),
#   ('International', 'I-E'),
#   ('Monetary', 'I-E'),
#   ('Fund', 'I-E'),
#   ('to', 'I-E'),
#   ('have', 'I-E'),
#   ('estimated', 'I-E'),
#   ('over', 'I-E'),
#   ('$', 'I-E'),
#   ('200', 'I-E'),
#   ('billion', 'I-E'),
#   ('per', 'I-E'),
#   ('year', 'I-E'),
#   ('as', 'I-E'),
#   ('being', 'I-E'),
#   ('lost', 'I-E'),
#   ('by', 'I-E'),
#   ('developing', 'I-E'),
#   ('countries', 'E-E'),
#   ('when', 'S-M'),
#   ('multinational', 'B-C'),
#   ('enterprises', 'I-C'),
#   ('do', 'I-C'),
#   ('not', 'I-C'),
#   ('pay', 'I-C'),
#   ('taxes', 'I-C'),
#   ('in', 'I-C'),
#   ('the', 'I-C'),
#   ('countries', 'I-C'),
#   ('where', 'I-C'),
#   ('they', 'I-C'),
#   ('made', 'I-C'),
#   ('the', 'I-C'),
#   ('profit', 'I-C'),
#   ('.', 'E-C')],
#  '0009.00005': [('If', 'B-C'),
#   ('we', 'I-C'),
#   ('get', 'I-C'),
#   ('the', 'I-C'),
#   ('tax', 'I-C'),
#   ('structure', 'I-C'),
#   ('right', 'I-C'),
#   (',', 'I-C'),
#   ('this', 'I-C'),
#   ('will', 'E-C'),
#   ('…', 'S-M'),
#   ('create', 'B-E'),
#   ('thousands', 'I-E'),
#   ('of', 'I-E'),
#   ('jobs', 'I-E'),
#   ('…', 'I-E'),
#   ('help', 'I-E'),
#   ('fund', 'I-E'),
#   ('the', 'I-E'),
#   ('State', 'I-E'),
#   ("'s", 'I-E'),
#   ('capital', 'I-E'),
#   ('plan', 'I-E'),
#   ('…', 'I-E'),
#   ('and', 'I-E'),
#   ('stop', 'I-E'),
#   ('the', 'I-E'),
#   ('flow', 'I-E'),
#   ('of', 'I-E'),
#   ('over', 'I-E'),
#   ('$', 'I-E'),
#   ('200', 'I-E'),
#   ('million', 'I-E'),
#   ('in', 'I-E'),
#   ('gaming', 'I-E'),
#   ('revenue', 'I-E'),
#   ('to', 'I-E'),
#   ('Indiana', 'I-E'),
#   ('.', 'E-E')],
#  '0009.00011': [('The', 'B-C'),
#   ('only', 'I-C'),
#   ('sizable', 'I-C'),
#   ('cash', 'I-C'),
#   ('flow', 'I-C'),
#   ('has', 'I-C'),
#   ('gone', 'I-C'),
#   ('to', 'I-C'),
#   ('the', 'I-C'),
#   ('Baltimore', 'I-C'),
#   ('Casino', 'I-C'),
#   ('Local', 'I-C'),
#   ('Development', 'I-C'),
#   ('Council', 'I-C'),
#   ('(', 'I-C'),
#   ('BLDC', 'I-C'),
#   (')', 'I-C'),
#   (',', 'I-C'),
#   ('with', 'I-C'),
#   ('the', 'I-C'),
#   ('lion', 'I-C'),
#   ("'s", 'I-C'),
#   ('share', 'I-C'),
#   ('of', 'I-C'),
#   ('those', 'I-C'),
#   ('funds', 'I-C'),
#   ('paying', 'I-C'),
#   ('for', 'I-C'),
#   ('city', 'I-C'),
#   ('services', 'I-C'),
#   ('that', 'I-C'),
#   ('chiefly', 'I-C'),
#   ('benefit', 'I-C'),
#   ('the', 'I-C'),
#   ('casino', 'I-C'),
#   ('.', 'E-C'),
#   ('BLDC', 'B-E'),
#   ("'s", 'I-E'),
#   ('2018', 'I-E'),
#   ('spending', 'I-E'),
#   ('budget', 'I-E'),
#   ('of', 'I-E'),
#   ('$', 'I-E'),
#   ('7.4', 'I-E'),
#   ('million', 'I-E'),
#   (',', 'I-E'),
#   ('for', 'I-E'),
#   ('example', 'I-E'),
#   (',', 'I-E'),
#   ('includes', 'I-E'),
#   ('more', 'I-E'),
#   ('than', 'I-E'),
#   ('$', 'I-E'),
#   ('1.6', 'I-E'),
#   ('million', 'I-E'),
#   ('for', 'I-E'),
#   ('police', 'I-E'),
#   ('protection', 'I-E'),
#   ('around', 'I-E'),
#   ('the', 'I-E'),
#   ('casino', 'I-E'),
#   (',', 'I-E'),
#   ('$', 'I-E'),
#   ('358,000', 'I-E'),
#   ('for', 'I-E'),
#   ('medic', 'I-E'),
#   ('services', 'I-E'),
#   (',', 'I-E'),
#   ('$', 'I-E'),
#   ('435,000', 'I-E'),
#   ('for', 'I-E'),
#   ('supplemental', 'I-E'),
#   ('garbage', 'I-E'),
#   ('collection', 'I-E'),
#   (',', 'I-E'),
#   ('$', 'I-E'),
#   ('540,000', 'I-E'),
#   ('to', 'I-E'),
#   ('staff', 'I-E'),
#   ('a', 'I-E'),
#   ('mayoral', 'I-E'),
#   ('employment', 'I-E'),
#   ('center', 'I-E'),
#   (',', 'I-E'),
#   ('and', 'I-E'),
#   ('$', 'I-E'),
#   ('2', 'I-E'),
#   ('million', 'I-E'),
#   ('for', 'I-E'),
#   ('infrastructure', 'I-E'),
#   ('improvements', 'I-E'),
#   ('around', 'I-E'),
#   ('the', 'I-E'),
#   ('casino', 'I-E'),
#   ('.', 'E-E')],
#  '0009.00013': [('In', 'B-C'),
#   ('the', 'I-C'),
#   ("'90s", 'I-C'),
#   (',', 'I-C'),
#   ('Detroit', 'I-C'),
#   ('built', 'I-C'),
#   ('casinos', 'I-C'),
#   ('to', 'I-C'),
#   ('compete', 'I-C'),
#   ('with', 'I-C'),
#   ('those', 'I-C'),
#   ('across', 'I-C'),
#   ('the', 'I-C'),
#   ('river', 'I-C'),
#   ('in', 'I-C'),
#   ('Windsor', 'I-C'),
#   (',', 'I-C'),
#   ('Canada', 'I-C'),
#   ('.', 'E-C'),
#   ('Their', 'B-E'),
#   ('revenue', 'I-E'),
#   ('ended', 'I-E'),
#   ('up', 'I-E'),
#   ('accounting', 'I-E'),
#   ('for', 'I-E'),
#   ('11', 'I-E'),
#   ('percent', 'I-E'),
#   ('of', 'I-E'),
#   ('the', 'I-E'),
#   ('city', 'I-E'),
#   ("'s", 'I-E'),
#   ('budget', 'I-E'),
#   (',', 'I-E'),
#   ('but', 'I-E'),
#   ('it', 'I-E'),
#   ('was', 'I-E'),
#   ("n't", 'I-E'),
#   ('enough', 'I-E'),
#   ('to', 'I-E'),
#   ('prevent', 'I-E'),
#   ('the', 'I-E'),
#   ('largest', 'I-E'),
#   ('municipal', 'I-E'),
#   ('bankruptcy', 'I-E'),
#   ('in', 'I-E'),
#   ('American', 'I-E'),
#   ('history', 'I-E'),
#   (',', 'I-E'),
#   ('in', 'I-E'),
#   ('2013', 'I-E'),
#   ('.', 'E-E')],
#  '0009.00024': [('The', 'B-C'),
#   ('city', 'I-C'),
#   ('wants', 'I-C'),
#   ('a', 'I-C'),
#   ('33-1/3', 'I-C'),
#   ('percent', 'I-C'),
#   ('tax', 'I-C'),
#   ('on', 'I-C'),
#   ('Adjusted', 'I-C'),
#   ('Gross', 'I-C'),
#   ('Receipts', 'I-C'),
#   ('(', 'I-C'),
#   ('the', 'I-C'),
#   ('total', 'I-C'),
#   ('earned', 'I-C'),
#   ('from', 'I-C'),
#   ('wagerers', 'I-C'),
#   ('after', 'I-C'),
#   ('prize', 'I-C'),
#   ('money', 'I-C'),
#   ('is', 'I-C'),
#   ('doled', 'I-C'),
#   ('out', 'I-C'),
#   (')', 'I-C'),
#   ('to', 'I-C'),
#   ('pay', 'I-C'),
#   ('for', 'I-C'),
#   ('police', 'I-C'),
#   ('and', 'I-C'),
#   ('fire', 'I-C'),
#   ('pensions', 'I-C'),
#   ('.', 'E-C'),
#   ('A', 'B-E'),
#   ('study', 'I-E'),
#   ('by', 'I-E'),
#   ('the', 'I-E'),
#   ('Illinois', 'I-E'),
#   ('Gaming', 'I-E'),
#   ('Board', 'I-E'),
#   ('found', 'I-E'),
#   ('that', 'I-E'),
#   ('such', 'I-E'),
#   ('a', 'I-E'),
#   ('tax', 'I-E'),
#   ('would', 'I-E'),
#   ('only', 'I-E'),
#   ('allow', 'I-E'),
#   ('a', 'I-E'),
#   ('casino', 'I-E'),
#   ('to', 'I-E'),
#   ('turn', 'I-E'),
#   ('a', 'I-E'),
#   ('1', 'I-E'),
#   ('or', 'I-E'),
#   ('2', 'I-E'),
#   ('percent', 'I-E'),
#   ('profit', 'I-E'),
#   (',', 'I-E'),
#   ('which', 'I-E'),
#   ('is', 'I-E'),
#   ('not', 'I-E'),
#   ('an', 'I-E'),
#   ('acceptable', 'I-E'),
#   ('rate', 'I-E'),
#   ('of', 'I-E'),
#   ('return', 'I-E'),
#   ('for', 'I-E'),
#   ('a', 'I-E'),
#   ('casino', 'I-E'),
#   ('operator', 'I-E'),
#   ('.', 'E-E')],
#  '0010.00008': [('Losses', 'B-C'),
#   ('at', 'I-C'),
#   ('its', 'I-C'),
#   ('Car', 'I-C'),
#   ('Store', 'I-C'),
#   ('segment', 'I-C'),
#   ('widened', 'I-C'),
#   ('to', 'I-C'),
#   ('19.1', 'I-C'),
#   ('million', 'I-C'),
#   ('pounds', 'I-C'),
#   ('.', 'E-C'),
#   ('To', 'B-E'),
#   ('revive', 'I-E'),
#   ('its', 'I-E'),
#   ('loss-making', 'I-E'),
#   ('Car', 'I-E'),
#   ('Store', 'I-E'),
#   ('unit', 'I-E'),
#   (',', 'I-E'),
#   ('Pendragon', 'I-E'),
#   ('said', 'I-E'),
#   ('it', 'I-E'),
#   ('will', 'I-E'),
#   ('shut', 'I-E'),
#   ('22', 'I-E'),
#   ('of', 'I-E'),
#   ('34', 'I-E'),
#   ('store', 'I-E'),
#   ('locations', 'I-E'),
#   ('identified', 'I-E'),
#   ('as', 'I-E'),
#   ('the', 'I-E'),
#   ('worst', 'I-E'),
#   ('performing', 'I-E'),
#   ('in', 'I-E'),
#   ('the', 'I-E'),
#   ('second', 'I-E'),
#   ('half', 'I-E'),
#   ('of', 'I-E'),
#   ('the', 'I-E'),
#   ('year', 'I-E'),
#   (',', 'I-E'),
#   ('leading', 'I-E'),
#   ('to', 'I-E'),
#   ('300', 'I-E'),
#   ('job', 'I-E'),
#   ('cuts', 'I-E'),
#   ('.', 'E-E')],
#  '0012.00023': [('Euro', 'B-C'),
#   ('exchange', 'I-C'),
#   ('rate', 'I-C'),
#   ('(', 'I-C'),
#   ('EUR/CHF', 'I-C'),
#   (')', 'I-C'),
#   (':', 'I-C'),
#   ('on', 'I-C'),
#   ('January', 'I-C'),
#   ('15', 'I-C'),
#   (',', 'I-C'),
#   ('2015', 'I-C'),
#   (',', 'I-C'),
#   ('at', 'I-C'),
#   ('9:30', 'I-C'),
#   ('a.m.', 'I-C'),
#   ('GMT', 'I-C'),
#   (',', 'I-C'),
#   ('the', 'I-C'),
#   ('SNB', 'I-C'),
#   ('abandoned', 'I-C'),
#   ('its', 'I-C'),
#   ('floor', 'I-C'),
#   ('on', 'I-C'),
#   ('the', 'I-C'),
#   ('EUR/CHF', 'I-C'),
#   ('exchange', 'I-C'),
#   ('rate', 'I-C'),
#   ('via', 'I-C'),
#   ('a', 'I-C'),
#   ('surprise', 'I-C'),
#   ('press', 'I-C'),
#   ('release', 'I-C'),
#   ('.', 'E-C'),
#   ('The', 'B-E'),
#   ('announcement', 'I-E'),
#   ('shocked', 'I-E'),
#   ('the', 'I-E'),
#   ('FX', 'I-E'),
#   ('market', 'I-E'),
#   ('-', 'I-E'),
#   ('EUR/CHF', 'I-E'),
#   ('dropped', 'I-E'),
#   ('12.3', 'I-E'),
#   ('percent', 'I-E'),
#   ('over', 'I-E'),
#   ('the', 'I-E'),
#   ('next', 'I-E'),
#   ('few', 'I-E'),
#   ('hours', 'I-E'),
#   ('.', 'E-E')],
#  '0012.00025': [('The', 'B-C'),
#   ('Leave', 'I-C'),
#   ('win', 'E-C'),
#   ('led', 'B-M'),
#   ('to', 'E-M'),
#   ('an', 'B-E'),
#   ('11', 'I-E'),
#   ('percent', 'I-E'),
#   ('drop', 'I-E'),
#   ('in', 'I-E'),
#   ('GBP/USD', 'I-E'),
#   ('overnight', 'I-E'),
#   ('.', 'E-E')],
#  '0012.00027': [('The', 'B-C'),
#   ('unexpected', 'I-C'),
#   ('Trump', 'I-C'),
#   ('victory', 'E-C'),
#   ('led', 'B-M'),
#   ('to', 'E-M'),
#   ('an', 'B-E'),
#   ('8.3', 'I-E'),
#   ('percent', 'I-E'),
#   ('rise', 'I-E'),
#   ('in', 'I-E'),
#   ('USD/MXN', 'I-E'),
#   ('overnight', 'I-E'),
#   ('.', 'E-E')],
#  '0013.00004': [('Many', 'B-C'),
#   ('of', 'I-C'),
#   ('Tunisia', 'I-C'),
#   ("'s", 'I-C'),
#   ('sacred', 'I-C'),
#   ('cows', 'I-C'),
#   ('have', 'I-C'),
#   ('fallen', 'I-C'),
#   (',', 'I-C'),
#   ('from', 'I-C'),
#   ('technocrat', 'I-C'),
#   ('Prime', 'I-C'),
#   ('Minister', 'I-C'),
#   ('Youssef', 'I-C'),
#   ('Chahed', 'I-C'),
#   ('to', 'I-C'),
#   ('Defense', 'I-C'),
#   ('Minister', 'I-C'),
#   ('Abdelkarim', 'I-C'),
#   ('Zbidi', 'I-C'),
#   ('and', 'I-C'),
#   ('moderate', 'I-C'),
#   ('Islamist', 'I-C'),
#   ('Ennahda', 'I-C'),
#   ("'s", 'I-C'),
#   ('Abdelfattah', 'I-C'),
#   ('Mourou', 'I-C'),
#   (',', 'I-C'),
#   ('all', 'I-C'),
#   ('of', 'I-C'),
#   ('whom', 'I-C'),
#   ('are', 'I-C'),
#   ('perceived', 'I-C'),
#   ('as', 'I-C'),
#   ('having', 'I-C'),
#   ('presided', 'I-C'),
#   ('over', 'I-C'),
#   ('the', 'I-C'),
#   ('country', 'I-C'),
#   ("'s", 'I-C'),
#   ('gradual', 'I-C'),
#   ('decline', 'I-C'),
#   ('and', 'I-C'),
#   ('fall', 'I-C'),
#   ('.', 'E-C'),
#   ('I', 'B-E'),
#   ('want', 'I-E'),
#   ('the', 'I-E'),
#   ('government', 'I-E'),
#   ('to', 'I-E'),
#   ('provide', 'I-E'),
#   ('jobs', 'I-E'),
#   ('and', 'I-E'),
#   ('money', 'I-E'),
#   ('to', 'I-E'),
#   ('young', 'I-E'),
#   ('people', 'I-E'),
#   ('for', 'I-E'),
#   ('projects', 'I-E'),
#   (',', 'I-E'),
#   ('said', 'I-E'),
#   ('Khalil', 'I-E'),
#   ('Mlouki', 'I-E'),
#   (',', 'I-E'),
#   ('a', 'I-E'),
#   ('univeristy', 'I-E'),
#   ('graduate', 'I-E'),
#   ('who', 'I-E'),
#   ('was', 'I-E'),
#   ('among', 'I-E'),
#   ('the', 'I-E'),
#   ('54', 'I-E'),
#   ('%', 'I-E'),
#   ('of', 'I-E'),
#   ('Tunisians', 'I-E'),
#   ('to', 'I-E'),
#   ('withhold', 'I-E'),
#   ('their', 'I-E'),
#   ('vote', 'I-E'),
#   ('.', 'E-E')],
#  '0015.00007': [('Oddur', 'B-C'),
#   ('Sigurðsson', 'I-C'),
#   (',', 'I-C'),
#   ('a', 'I-C'),
#   ('glaciologist', 'I-C'),
#   ('at', 'I-C'),
#   ('the', 'I-C'),
#   ('Icelandic', 'I-C'),
#   ('Meteorological', 'I-C'),
#   ('Office', 'I-C'),
#   (',', 'I-C'),
#   ('forecasts', 'I-C'),
#   ('that', 'I-C'),
#   ('all', 'I-C'),
#   ('of', 'I-C'),
#   ('Iceland', 'I-C'),
#   ("'s", 'I-C'),
#   ('300', 'I-C'),
#   ('or', 'I-C'),
#   ('so', 'I-C'),
#   ('named', 'I-C'),
#   ('glaciers', 'I-C'),
#   ('will', 'I-C'),
#   ('melt', 'I-C'),
#   ('within', 'I-C'),
#   ('200', 'I-C'),
#   ('years', 'I-C'),
#   (',', 'E-C'),
#   ('raising', 'B-E'),
#   ('global', 'I-E'),
#   ('sea', 'I-E'),
#   ('levels', 'I-E'),
#   ('by', 'I-E'),
#   ('1', 'I-E'),
#   ('centimeter', 'I-E'),
#   ('(', 'I-E'),
#   ('0.4', 'I-E'),
#   ('of', 'I-E'),
#   ('an', 'I-E'),
#   ('inch', 'I-E'),
#   (')', 'I-E'),
#   ('.', 'E-E')],
#  '0015.00008': [('Worldwide', 'B-C'),
#   (',', 'I-C'),
#   ('390', 'I-C'),
#   ('billion', 'I-C'),
#   ('tons', 'I-C'),
#   ('of', 'I-C'),
#   ('glacial', 'I-C'),
#   ('ice', 'I-C'),
#   ('melts', 'I-C'),
#   ('annually', 'I-C'),
#   (',', 'E-C'),
#   ('contributing', 'B-E'),
#   ('about', 'I-E'),
#   ('a', 'I-E'),
#   ('third', 'I-E'),
#   ('to', 'I-E'),
#   ('the', 'I-E'),
#   ('rise', 'I-E'),
#   ('in', 'I-E'),
#   ('global', 'I-E'),
#   ('sea', 'I-E'),
#   ('levels', 'I-E'),
#   (',', 'I-E'),
#   ('according', 'I-E'),
#   ('to', 'I-E'),
#   ('a', 'I-E'),
#   ('scientific', 'I-E'),
#   ('paper', 'I-E'),
#   ('in', 'I-E'),
#   ('the', 'I-E'),
#   ('journal', 'I-E'),
#   ('Nature', 'I-E'),
#   ('this', 'I-E'),
#   ('year', 'I-E'),
#   ('.', 'E-E')],
#  '0015.00011': [('Mitigating', 'B-C'),
#   ('climate', 'I-C'),
#   ('change', 'I-C'),
#   ('is', 'I-C'),
#   ('one', 'I-C'),
#   ('of', 'I-C'),
#   ('the', 'I-C'),
#   ('top', 'I-C'),
#   ('priorities', 'I-C'),
#   ('of', 'I-C'),
#   ('the', 'I-C'),
#   ('government', 'I-C'),
#   (',', 'I-C'),
#   ('Guðmundur', 'I-C'),
#   ('Ingi', 'I-C'),
#   ('Guðbrandsson', 'I-C'),
#   (',', 'I-C'),
#   ('Iceland', 'I-C'),
#   ("'s", 'I-C'),
#   ('environment', 'I-C'),
#   ('minister', 'I-C'),
#   (',', 'I-C'),
#   ('told', 'I-C'),
#   ('NBC', 'I-C'),
#   ('News', 'I-C'),
#   ('.', 'E-C'),
#   ('We', 'B-M'),
#   ('need', 'I-M'),
#   ('to', 'I-M'),
#   ('scale', 'I-M'),
#   ('up', 'I-M'),
#   ('our', 'I-M'),
#   ('efforts', 'I-M'),
#   ('and', 'I-M'),
#   ('step', 'I-M'),
#   ('up', 'I-M'),
#   ('our', 'I-M'),
#   ('game', 'I-M'),
#   ('when', 'I-M'),
#   ('it', 'I-M'),
#   ('comes', 'I-M'),
#   ('to', 'I-M'),
#   ('solving', 'I-M'),
#   ('the', 'I-M'),
#   ('climate', 'I-M'),
#   ('crisis', 'I-M'),
#   ('.', 'E-M'),
#   ('Iceland', 'B-E'),
#   ('has', 'I-E'),
#   ('pledged', 'I-E'),
#   ('to', 'I-E'),
#   ('cut', 'I-E'),
#   ('its', 'I-E'),
#   ('emissions', 'I-E'),
#   ('by', 'I-E'),
#   ('40', 'I-E'),
#   ('%', 'I-E'),
#   ('by', 'I-E'),
#   ('2030', 'I-E'),
#   ('and', 'I-E'),
#   ('aims', 'I-E'),
#   ('to', 'I-E'),
#   ('be', 'I-E'),
#   ('carbon', 'I-E'),
#   ('neutral', 'I-E'),
#   ('by', 'I-E'),
#   ('2040', 'I-E'),
#   ('.', 'E-E')],
#  '0017.00003': [('The', 'B-E'),
#   ('U.S.', 'I-E'),
#   ('Treasury', 'I-E'),
#   ('Department', 'I-E'),
#   ('said', 'I-E'),
#   ('on', 'I-E'),
#   ('Wednesday', 'I-E'),
#   ('it', 'I-E'),
#   ('was', 'I-E'),
#   ('imposing', 'I-E'),
#   ('sanctions', 'I-E'),
#   ('on', 'I-E'),
#   ('five', 'I-E'),
#   ('Chinese', 'I-E'),
#   ('nationals', 'I-E'),
#   ('and', 'I-E'),
#   ('six', 'I-E'),
#   ('entities', 'E-E'),
#   ('that', 'S-M'),
#   ('it', 'B-C'),
#   ('said', 'I-C'),
#   ('had', 'I-C'),
#   ('violated', 'I-C'),
#   ('Washington', 'I-C'),
#   ("'s", 'I-C'),
#   ('unilateral', 'I-C'),
#   ('curbs', 'I-C'),
#   ('on', 'I-C'),
#   ('Tehran', 'I-C'),
#   (',', 'I-C'),
#   ('These', 'I-C'),
#   ('included', 'I-C'),
#   ('two', 'I-C'),
#   ('Cosco', 'I-C'),
#   ('Shipping', 'I-C'),
#   ('Corporation', 'I-C'),
#   ('subsidiaries', 'I-C'),
#   (',', 'I-C'),
#   ('Cosco', 'I-C'),
#   ('Shipping', 'I-C'),
#   ('Tanker', 'I-C'),
#   ('Dalian', 'I-C'),
#   ('and', 'I-C'),
#   ('Cosco', 'I-C'),
#   ('Shipping', 'I-C'),
#   ('Tanker', 'I-C'),
#   ('(', 'I-C'),
#   ('Dalian', 'I-C'),
#   (')', 'I-C'),
#   ('Seaman', 'I-C'),
#   ('and', 'I-C'),
#   ('Ship', 'I-C'),
#   ('Management', 'I-C'),
#   ('Co', 'I-C'),
#   ('Ltd', 'I-C'),
#   ('.', 'E-C')],
#  '0018.00001.1': [('Park', 'B-C'),
#   ('Hotels', 'I-C'),
#   ('&', 'I-C'),
#   ('Resorts', 'I-C'),
#   ('Inc', 'I-C'),
#   ('(', 'I-C'),
#   ('NYSE', 'I-C'),
#   (':', 'I-C'),
#   ('PK', 'I-C'),
#   (')', 'I-C'),
#   ('Plans', 'I-C'),
#   ('Quarterly', 'I-C'),
#   ('Dividend', 'I-C'),
#   ('of', 'I-C'),
#   ('$', 'I-C'),
#   ('0.45', 'I-C'),
#   ('.', 'E-C'),
#   ('Stockholders', 'B-E'),
#   ('of', 'I-E'),
#   ('record', 'I-E'),
#   ('on', 'I-E'),
#   ('Monday', 'I-E'),
#   (',', 'I-E'),
#   ('September', 'I-E'),
#   ('30th', 'I-E'),
#   ('will', 'I-E'),
#   ('be', 'I-E'),
#   ('given', 'I-E'),
#   ('a', 'I-E'),
#   ('dividend', 'I-E'),
#   ('of', 'I-E'),
#   ('0.45', 'I-E'),
#   ('per', 'I-E'),
#   ('share', 'I-E'),
#   ('by', 'I-E'),
#   ('the', 'I-E'),
#   ('financial', 'I-E'),
#   ('services', 'I-E'),
#   ('provider', 'I-E'),
#   ('on', 'I-E'),
#   ('Tuesday', 'I-E'),
#   (',', 'I-E'),
#   ('October', 'I-E'),
#   ('15th', 'I-E'),
#   ('.', 'E-E'),
#   ('This', 'B-A'),
#   ('represents', 'I-A'),
#   ('a', 'I-A'),
#   ('$', 'I-A'),
#   ('1.80', 'I-A'),
#   ('annualized', 'I-A'),
#   ('dividend', 'I-A'),
#   ('and', 'I-A'),
#   ('a', 'I-A'),
#   ('dividend', 'I-A'),
#   ('yield', 'I-A'),
#   ('of', 'I-A'),
#   ('7.19', 'I-A'),
#   ('%', 'I-A'),
#   ('.', 'E-A')],
#  '0018.00001.2': [('Park', 'B-C'),
#   ('Hotels', 'I-C'),
#   ('&', 'I-C'),
#   ('Resorts', 'I-C'),
#   ('Inc', 'I-C'),
#   ('(', 'I-C'),
#   ('NYSE', 'I-C'),
#   (':', 'I-C'),
#   ('PK', 'I-C'),
#   (')', 'I-C'),
#   ('Plans', 'I-C'),
#   ('Quarterly', 'I-C'),
#   ('Dividend', 'I-C'),
#   ('of', 'I-C'),
#   ('$', 'I-C'),
#   ('0.45', 'I-C'),
#   ('.', 'E-C'),
#   ('Stockholders', 'B-M'),
#   ('of', 'I-M'),
#   ('record', 'I-M'),
#   ('on', 'I-M'),
#   ('Monday', 'I-M'),
#   (',', 'I-M'),
#   ('September', 'I-M'),
#   ('30th', 'I-M'),
#   ('will', 'I-M'),
#   ('be', 'I-M'),
#   ('given', 'I-M'),
#   ('a', 'I-M'),
#   ('dividend', 'I-M'),
#   ('of', 'I-M'),
#   ('0.45', 'I-M'),
#   ('per', 'I-M'),
#   ('share', 'I-M'),
#   ('by', 'I-M'),
#   ('the', 'I-M'),
#   ('financial', 'I-M'),
#   ('services', 'I-M'),
#   ('provider', 'I-M'),
#   ('on', 'I-M'),
#   ('Tuesday', 'I-M'),
#   (',', 'I-M'),
#   ('October', 'I-M'),
#   ('15th', 'I-M'),
#   ('.', 'E-M'),
#   ('This', 'B-E'),
#   ('represents', 'I-E'),
#   ('a', 'I-E'),
#   ('$', 'I-E'),
#   ('1.80', 'I-E'),
#   ('annualized', 'I-E'),
#   ('dividend', 'I-E'),
#   ('and', 'I-E'),
#   ('a', 'I-E'),
#   ('dividend', 'I-E'),
#   ('yield', 'I-E'),
#   ('of', 'I-E'),
#   ('7.19', 'I-E'),
#   ('%', 'I-E'),
#   ('.', 'E-E')],
#  '0018.00003': [('Analysts', 'B-C'),
#   ('expect', 'I-C'),
#   ('Park', 'I-C'),
#   ('Hotels', 'I-C'),
#   ('&', 'I-C'),
#   ('Resorts', 'I-C'),
#   ('to', 'I-C'),
#   ('earn', 'I-C'),
#   ('$', 'I-C'),
#   ('2.89', 'I-C'),
#   ('per', 'I-C'),
#   ('share', 'I-C'),
#   ('next', 'I-C'),
#   ('year', 'I-C'),
#   (',', 'E-C'),
#   ('which', 'B-M'),
#   ('means', 'E-M'),
#   ('the', 'B-E'),
#   ('company', 'I-E'),
#   ('should', 'I-E'),
#   ('continue', 'I-E'),
#   ('to', 'I-E'),
#   ('be', 'I-E'),
#   ('able', 'I-E'),
#   ('to', 'I-E'),
#   ('cover', 'I-E'),
#   ('its', 'I-E'),
#   ('$', 'I-E'),
#   ('1.80', 'I-E'),
#   ('annual', 'I-E'),
#   ('dividend', 'I-E'),
#   ('with', 'I-E'),
#   ('an', 'I-E'),
#   ('expected', 'I-E'),
#   ('future', 'I-E'),
#   ('payout', 'I-E'),
#   ('ratio', 'I-E'),
#   ('of', 'I-E'),
#   ('62.3', 'I-E'),
#   ('%', 'I-E'),
#   ('.', 'E-E')],
#  '0018.00004': [('Shares', 'B-C'),
#   ('of', 'I-C'),
#   ('PK', 'I-C'),
#   ('stock', 'I-C'),
#   ('traded', 'I-C'),
#   ('down', 'I-C'),
#   ('$', 'I-C'),
#   ('0.24', 'I-C'),
#   ('during', 'I-C'),
#   ('mid-day', 'I-C'),
#   ('trading', 'I-C'),
#   ('on', 'I-C'),
#   ('Wednesday', 'I-C'),
#   (',', 'E-C'),
#   ('hitting', 'B-E'),
#   ('$', 'I-E'),
#   ('25.04', 'I-E'),
#   ('.', 'E-E'),
#   ('2,906,672', 'B-A'),
#   ('shares', 'I-A'),
#   ('of', 'I-A'),
#   ('the', 'I-A'),
#   ('company', 'I-A'),
#   ("'s", 'I-A'),
#   ('stock', 'I-A'),
#   ('were', 'I-A'),
#   ('exchanged', 'I-A'),
#   (',', 'I-A'),
#   ('compared', 'I-A'),
#   ('to', 'I-A'),
#   ('its', 'I-A'),
#   ('average', 'I-A'),
#   ('volume', 'I-A'),
#   ('of', 'I-A'),
#   ('2,058,218', 'I-A'),
#   ('.', 'E-A')],
#  '0018.00008': [('The', 'B-C'),
#   ('financial', 'I-C'),
#   ('services', 'I-C'),
#   ('provider', 'I-C'),
#   ('reported', 'I-C'),
#   ('$', 'I-C'),
#   ('0.40', 'I-C'),
#   ('earnings', 'I-C'),
#   ('per', 'I-C'),
#   ('share', 'I-C'),
#   ('(', 'I-C'),
#   ('EPS', 'I-C'),
#   (')', 'I-C'),
#   ('for', 'I-C'),
#   ('the', 'I-C'),
#   ('quarter', 'I-C'),
#   (',', 'E-C'),
#   ('missing', 'B-E'),
#   ('the', 'I-E'),
#   ('consensus', 'I-E'),
#   ('estimate', 'I-E'),
#   ('of', 'I-E'),
#   ('$', 'I-E'),
#   ('0.82', 'I-E'),
#   ('by', 'I-E'),
#   ('(', 'I-E'),
#   ('$', 'I-E'),
#   ('0.42', 'I-E'),
#   (')', 'I-E'),
#   ('.', 'E-E')],
#  '0018.00015.1': [('Finally', 'B-C'),
#   (',', 'I-C'),
#   ('Deutsche', 'I-C'),
#   ('Bank', 'I-C'),
#   ('set', 'I-C'),
#   ('a', 'I-C'),
#   ('$', 'I-C'),
#   ('33.00', 'I-C'),
#   ('price', 'I-C'),
#   ('objective', 'I-C'),
#   ('on', 'I-C'),
#   ('Park', 'I-C'),
#   ('Hotels', 'I-C'),
#   ('&', 'I-C'),
#   ('Resorts', 'I-C'),
#   ('and', 'I-C'),
#   ('gave', 'I-C'),
#   ('the', 'I-C'),
#   ('stock', 'I-C'),
#   ('a', 'I-C'),
#   ('hold', 'I-C'),
#   ('rating', 'I-C'),
#   ('in', 'I-C'),
#   ('a', 'I-C'),
#   ('report', 'I-C'),
#   ('on', 'I-C'),
#   ('Wednesday', 'I-C'),
#   (',', 'I-C'),
#   ('July', 'I-C'),
#   ('31st', 'I-C'),
#   ('.', 'E-C'),
#   ('One', 'B-M'),
#   ('analyst', 'I-M'),
#   ('has', 'I-M'),
#   ('rated', 'I-M'),
#   ('the', 'I-M'),
#   ('stock', 'I-M'),
#   ('with', 'I-M'),
#   ('a', 'I-M'),
#   ('sell', 'I-M'),
#   ('rating', 'I-M'),
#   (',', 'I-M'),
#   ('six', 'I-M'),
#   ('have', 'I-M'),
#   ('given', 'I-M'),
#   ('a', 'I-M'),
#   ('hold', 'I-M'),
#   ('rating', 'I-M'),
#   ('and', 'I-M'),
#   ('four', 'I-M'),
#   ('have', 'I-M'),
#   ('assigned', 'I-M'),
#   ('a', 'I-M'),
#   ('buy', 'I-M'),
#   ('rating', 'I-M'),
#   ('to', 'I-M'),
#   ('the', 'I-M'),
#   ('stock', 'I-M'),
#   ('.', 'E-M'),
#   ('The', 'B-E'),
#   ('company', 'I-E'),
#   ('presently', 'I-E'),
#   ('has', 'I-E'),
#   ('an', 'I-E'),
#   ('average', 'I-E'),
#   ('rating', 'I-E'),
#   ('of', 'I-E'),
#   ('Hold', 'I-E'),
#   ('and', 'I-E'),
#   ('an', 'I-E'),
#   ('average', 'I-E'),
#   ('price', 'I-E'),
#   ('target', 'I-E'),
#   ('of', 'I-E'),
#   ('$', 'I-E'),
#   ('30.27', 'I-E'),
#   ('.', 'E-E')],
#  '0018.00015.2': [('Finally', 'B-B'),
#   (',', 'I-B'),
#   ('Deutsche', 'I-B'),
#   ('Bank', 'I-B'),
#   ('set', 'I-B'),
#   ('a', 'I-B'),
#   ('$', 'I-B'),
#   ('33.00', 'I-B'),
#   ('price', 'I-B'),
#   ('objective', 'I-B'),
#   ('on', 'I-B'),
#   ('Park', 'I-B'),
#   ('Hotels', 'I-B'),
#   ('&', 'I-B'),
#   ('Resorts', 'I-B'),
#   ('and', 'I-B'),
#   ('gave', 'I-B'),
#   ('the', 'I-B'),
#   ('stock', 'I-B'),
#   ('a', 'I-B'),
#   ('hold', 'I-B'),
#   ('rating', 'I-B'),
#   ('in', 'I-B'),
#   ('a', 'I-B'),
#   ('report', 'I-B'),
#   ('on', 'I-B'),
#   ('Wednesday', 'I-B'),
#   (',', 'I-B'),
#   ('July', 'I-B'),
#   ('31st', 'I-B'),
#   ('.', 'E-B'),
#   ('One', 'B-C'),
#   ('analyst', 'I-C'),
#   ('has', 'I-C'),
#   ('rated', 'I-C'),
#   ('the', 'I-C'),
#   ('stock', 'I-C'),
#   ('with', 'I-C'),
#   ('a', 'I-C'),
#   ('sell', 'I-C'),
#   ('rating', 'I-C'),
#   (',', 'I-C'),
#   ('six', 'I-C'),
#   ('have', 'I-C'),
#   ('given', 'I-C'),
#   ('a', 'I-C'),
#   ('hold', 'I-C'),
#   ('rating', 'I-C'),
#   ('and', 'I-C'),
#   ('four', 'I-C'),
#   ('have', 'I-C'),
#   ('assigned', 'I-C'),
#   ('a', 'I-C'),
#   ('buy', 'I-C'),
#   ('rating', 'I-C'),
#   ('to', 'I-C'),
#   ('the', 'I-C'),
#   ('stock', 'I-C'),
#   ('.', 'E-C'),
#   ('The', 'B-E'),
#   ('company', 'I-E'),
#   ('presently', 'I-E'),
#   ('has', 'I-E'),
#   ('an', 'I-E'),
#   ('average', 'I-E'),
#   ('rating', 'I-E'),
#   ('of', 'I-E'),
#   ('Hold', 'I-E'),
#   ('and', 'I-E'),
#   ('an', 'I-E'),
#   ('average', 'I-E'),
#   ('price', 'I-E'),
#   ('target', 'I-E'),
#   ('of', 'I-E'),
#   ('$', 'I-E'),
#   ('30.27', 'I-E'),
#   ('.', 'E-E')],
#  '0021.00006': [('Not', 'B-C'),
#   ('now', 'I-C'),
#   (',', 'I-C'),
#   ('the', 'I-C'),
#   ('split', 'I-C'),
#   ('is', 'I-C'),
#   ('too', 'I-C'),
#   ('great', 'I-C'),
#   ('and', 'I-C'),
#   ('there', 'I-C'),
#   ('is', 'I-C'),
#   ('no', 'I-C'),
#   ('way', 'I-C'),
#   ('to', 'I-C'),
#   ('get', 'I-C'),
#   ('Treasury', 'I-C'),
#   ('back', 'I-C'),
#   ('in', 'I-C'),
#   ('line', 'I-C'),
#   ('except', 'I-C'),
#   ('with', 'I-C'),
#   ('a', 'I-C'),
#   ('Nixon', 'I-C'),
#   ('Shock', 'I-C'),
#   ('.', 'E-C'),
#   ('The', 'B-E'),
#   ('private', 'I-E'),
#   ('banking', 'I-E'),
#   ('system', 'I-E'),
#   ('can', 'I-E'),
#   ('not', 'I-E'),
#   ('keep', 'I-E'),
#   ('up', 'I-E'),
#   ('with', 'I-E'),
#   ('the', 'I-E'),
#   ('10', 'I-E'),
#   ('%', 'I-E'),
#   ('increase', 'I-E'),
#   ('in', 'I-E'),
#   ('interest', 'I-E'),
#   ('charges', 'I-E'),
#   ('that', 'I-E'),
#   ('Treasury', 'I-E'),
#   ('is', 'I-E'),
#   ('looking', 'I-E'),
#   ('at', 'I-E'),
#   ('.', 'E-E')],
#  '0022.00001.1': [('Firm', 'B-C'),
#   ('Capital', 'I-C'),
#   ('Mortgage', 'I-C'),
#   ('Investment', 'I-C'),
#   ('Corp', 'I-C'),
#   ('(', 'I-C'),
#   ('TSE', 'I-C'),
#   (':', 'I-C'),
#   ('FC', 'I-C'),
#   (')', 'I-C'),
#   ('to', 'I-C'),
#   ('Issue', 'I-C'),
#   ('Monthly', 'I-C'),
#   ('Dividend', 'I-C'),
#   ('of', 'I-C'),
#   ('$', 'I-C'),
#   ('0.08', 'I-C'),
#   ('Tweet', 'I-C'),
#   ('Firm', 'I-C'),
#   ('Capital', 'I-C'),
#   ('Mortgage', 'I-C'),
#   ('Investment', 'I-C'),
#   ('Corp', 'I-C'),
#   ('(', 'I-C'),
#   ('TSE', 'I-C'),
#   (':', 'I-C'),
#   ('FC', 'I-C'),
#   (')', 'I-C'),
#   ('declared', 'I-C'),
#   ('a', 'I-C'),
#   ('monthly', 'I-C'),
#   ('dividend', 'I-C'),
#   ('on', 'I-C'),
#   ('Friday', 'I-C'),
#   (',', 'I-C'),
#   ('September', 'I-C'),
#   ('27th', 'I-C'),
#   (',', 'I-C'),
#   ('TickerTech', 'I-C'),
#   ('reports', 'I-C'),
#   ('.', 'E-C'),
#   ('Investors', 'B-E'),
#   ('of', 'I-E'),
#   ('record', 'I-E'),
#   ('on', 'I-E'),
#   ('Tuesday', 'I-E'),
#   (',', 'I-E'),
#   ('October', 'I-E'),
#   ('15th', 'I-E'),
#   ('will', 'I-E'),
#   ('be', 'I-E'),
#   ('given', 'I-E'),
#   ('a', 'I-E'),
#   ('dividend', 'I-E'),
#   ('of', 'I-E'),
#   ('0.078', 'I-E'),
#   ('per', 'I-E'),
#   ('share', 'I-E'),
#   ('on', 'I-E'),
#   ('Tuesday', 'I-E'),
#   (',', 'I-E'),
#   ('October', 'I-E'),
#   ('15th', 'I-E'),
#   ('.', 'E-E'),
#   ('This', 'B-A'),
#   ('represents', 'I-A'),
#   ('a', 'I-A'),
#   ('$', 'I-A'),
#   ('0.94', 'I-A'),
#   ('dividend', 'I-A'),
#   ('on', 'I-A'),
#   ('an', 'I-A'),
#   ('annualized', 'I-A'),
#   ('basis', 'I-A'),
#   ('and', 'I-A'),
#   ('a', 'I-A'),
#   ('dividend', 'I-A'),
#   ('yield', 'I-A'),
#   ('of', 'I-A'),
#   ('6.71', 'I-A'),
#   ('%', 'I-A'),
#   ('.', 'E-A')],
#  '0022.00001.2': [('Firm', 'B-C'),
#   ('Capital', 'I-C'),
#   ('Mortgage', 'I-C'),
#   ('Investment', 'I-C'),
#   ('Corp', 'I-C'),
#   ('(', 'I-C'),
# ...
#   ('a', 'I-E'),
#   ('paternity', 'I-E'),
#   ('leave', 'I-E'),
#   ('case', 'I-E'),
#   ('for', 'I-E'),
#   ('$', 'I-E'),
#   ('5', 'I-E'),
#   ('million', 'I-E'),
#   ('.', 'E-E')],
#  '0510.00058': [('The', 'B-C'),
#   ('settlement', 'I-C'),
#   ('calls', 'I-C'),
#   ('on', 'I-C'),
#   ('JP', 'I-C'),
#   ('Morgan', 'I-C'),
#   ('Chase', 'I-C'),
#   ('to', 'I-C'),
#   (':', 'I-C'),
#   ('Maintain', 'I-C'),
#   ('a', 'I-C'),
#   ('gender-neutral', 'I-C'),
#   ('parental', 'I-C'),
#   ('leave', 'I-C'),
#   ('policy', 'I-C'),
#   ('.', 'E-C'),
#   ('Train', 'B-M'),
#   ('HR', 'I-M'),
#   ('staffers', 'I-M'),
#   ('and', 'I-M'),
#   ('managers', 'I-M'),
#   ('on', 'I-M'),
#   ('how', 'I-M'),
#   ('to', 'I-M'),
#   ('administer', 'I-M'),
#   ('a', 'I-M'),
#   ('gender-neutral', 'I-M'),
#   ('parental', 'I-M'),
#   ('leave', 'I-M'),
#   ('policy', 'I-M'),
#   ('.', 'E-M'),
#   ('Pay', 'B-E'),
#   ('$', 'I-E'),
#   ('5', 'I-E'),
#   ('million', 'I-E'),
#   ('to', 'I-E'),
#   ('company', 'I-E'),
#   ('dads', 'I-E'),
#   ('who', 'I-E'),
#   ('said', 'I-E'),
#   ('they', 'I-E'),
#   ('were', 'I-E'),
#   ('blocked', 'I-E'),
#   ('by', 'I-E'),
#   ('the', 'I-E'),
#   ('bank', 'I-E'),
#   ('from', 'I-E'),
#   ('leveraging', 'I-E'),
#   ('additional', 'I-E'),
#   ('paid', 'I-E'),
#   ('parental', 'I-E'),
#   ('leave', 'I-E'),
#   ('as', 'I-E'),
#   ('primary', 'I-E'),
#   ('caregivers', 'I-E'),
#   ('.', 'E-E')],
#  '0513.00004': [('Recall', 'B-E'),
#   ('that', 'I-E'),
#   ('a', 'I-E'),
#   ('British', 'I-E'),
#   ('Commercial', 'I-E'),
#   ('Court', 'I-E'),
#   ('had', 'I-E'),
#   ('on', 'I-E'),
#   ('August', 'I-E'),
#   ('16', 'I-E'),
#   (',', 'I-E'),
#   ('awarded', 'I-E'),
#   ('judgment', 'I-E'),
#   ('in', 'I-E'),
#   ('the', 'I-E'),
#   ('sum', 'I-E'),
#   ('of', 'I-E'),
#   ('$', 'I-E'),
#   ('9.6bn', 'I-E'),
#   ('against', 'I-E'),
#   ('Nigeria', 'E-E'),
#   ('over', 'S-M'),
#   ('a', 'B-C'),
#   ('failed', 'I-C'),
#   ('contract', 'I-C'),
#   ('between', 'I-C'),
#   ('P', 'I-C'),
#   ('&', 'I-C'),
#   ('ID', 'I-C'),
#   ('and', 'I-C'),
#   ('the', 'I-C'),
#   ('Federal', 'I-C'),
#   ('Ministry', 'I-C'),
#   ('of', 'I-C'),
#   ('Petroleum', 'I-C'),
#   ('Resources', 'I-C'),
#   ('in', 'I-C'),
#   ('2010', 'I-C'),
#   ('.', 'E-C')],
#  '0513.00006': [('Catch', 'B-C'),
#   ('all', 'I-C'),
#   ('the', 'I-C'),
#   ('Scoop', 'I-C'),
#   ('on', 'I-C'),
#   ('www.bellanaija.com', 'I-C'),
#   ('Follow', 'I-C'),
#   ('us', 'I-C'),
#   ('Twitter', 'I-C'),
#   (':', 'I-C'),
#   ('@', 'I-C'),
#   ('bellanaija', 'I-C'),
#   ('Facebook', 'I-C'),
#   (':', 'I-C'),
#   ('@', 'I-C'),
#   ('bellanaija', 'I-C'),
#   ('Instagram', 'I-C'),
#   (':', 'I-C'),
#   ('@', 'I-C'),
#   ('bellanaijaonline', 'I-C'),
#   ('Court', 'I-C'),
#   ('gives', 'I-C'),
#   ('Engineering', 'I-C'),
#   ('Firm', 'I-C'),
#   ('Permission', 'E-C'),
#   ('to', 'S-M'),
#   ('Seize', 'B-E'),
#   ('Nigeria', 'I-E'),
#   ("'s", 'I-E'),
#   ('Assets', 'I-E'),
#   ('Worth', 'I-E'),
#   ('$', 'I-E'),
#   ('9bn', 'I-E'),
#   ('By', 'I-E'),
#   ('BellaNaija.c', 'E-E'),
#   ('om', 'S-A')],
#  '0515.00002': [('(', 'B-E'),
#   ('PIXABAY', 'I-E'),
#   ('/', 'I-E'),
#   ('MANILA', 'I-E'),
#   ('BULLETIN', 'I-E'),
#   (')', 'I-E'),
#   ('The', 'I-E'),
#   ('Court', 'I-E'),
#   ('of', 'I-E'),
#   ('Tax', 'I-E'),
#   ('Appeals', 'I-E'),
#   ('(', 'I-E'),
#   ('CTA', 'I-E'),
#   (')', 'I-E'),
#   ('also', 'I-E'),
#   ('exempted', 'I-E'),
#   ('Rosalinda', 'I-E'),
#   ('Valisno', 'I-E'),
#   ('Cando', 'I-E'),
#   (',', 'I-E'),
#   ('owner', 'I-E'),
#   ('of', 'I-E'),
#   ('Gasat', 'I-E'),
#   ('Express', 'I-E'),
#   ('of', 'I-E'),
#   ('San', 'I-E'),
#   ('Jose', 'I-E'),
#   ('Del', 'I-E'),
#   ('Monte', 'I-E'),
#   (',', 'I-E'),
#   ('Bulacan', 'I-E'),
#   ('from', 'I-E'),
#   ('paying', 'I-E'),
#   ('the', 'I-E'),
#   ('BIR', 'I-E'),
#   ('more', 'I-E'),
#   ('than', 'I-E'),
#   ('P2.2', 'I-E'),
#   ('million', 'I-E'),
#   ('in', 'I-E'),
#   ('tax', 'I-E'),
#   ('debts', 'I-E'),
#   ('.', 'E-E'),
#   ('In', 'B-C'),
#   ('an', 'I-C'),
#   ('18-page', 'I-C'),
#   ('decision', 'I-C'),
#   (',', 'I-C'),
#   ('the', 'I-C'),
#   ('court', 'I-C'),
#   ("'s", 'I-C'),
#   ('First', 'I-C'),
#   ('Division', 'I-C'),
#   ('dismissed', 'I-C'),
#   ('the', 'I-C'),
#   ('BIR', 'I-C'),
#   ('stand', 'I-C'),
#   ('that', 'I-C'),
#   ('it', 'I-C'),
#   ('sent', 'I-C'),
#   ('via', 'I-C'),
#   ('registered', 'I-C'),
#   ('mail', 'I-C'),
#   ('assessment', 'I-C'),
#   ('notices', 'I-C'),
#   ('to', 'I-C'),
#   ('the', 'I-C'),
#   ('accused', 'I-C'),
#   (',', 'I-C'),
#   ('including', 'I-C'),
#   ('the', 'I-C'),
#   ('Letter', 'I-C'),
#   ('of', 'I-C'),
#   ('Authority', 'I-C'),
#   ('to', 'I-C'),
#   ('Investigate', 'I-C'),
#   (',', 'I-C'),
#   ('Preliminary', 'I-C'),
#   ('and', 'I-C'),
#   ('Final', 'I-C'),
#   ('Assesment', 'I-C'),
#   ('Notices', 'I-C'),
#   ('.', 'E-C')],
#  '0516.00001': [('By', 'B-C'),
#   ('TgMedia', 'I-C'),
#   ('-', 'I-C'),
#   ('40', 'I-C'),
#   ('0', 'I-C'),
#   ('SHARE', 'I-C'),
#   ('Facebook', 'I-C'),
#   ('Twitter', 'I-C'),
#   ('United', 'I-C'),
#   ('States', 'I-C'),
#   ('Consulate', 'I-C'),
#   ('Launches', 'I-C'),
#   ('Academy', 'I-C'),
#   ('For', 'I-C'),
#   ('Women', 'I-C'),
#   ('Entrepreneurs', 'I-C'),
#   ('United', 'I-C'),
#   ('States', 'I-C'),
#   ('Consulate', 'I-C'),
#   ('General', 'I-C'),
#   ('in', 'I-C'),
#   ('Lagos', 'I-C'),
#   ('on', 'I-C'),
#   ('Monday', 'I-C'),
#   ('launched', 'I-C'),
#   ('the', 'I-C'),
#   ('Academy', 'I-C'),
#   ('for', 'I-C'),
#   ('Women', 'I-C'),
#   ('Entrepreneurs', 'I-C'),
#   ('(', 'I-C'),
#   ('AWE', 'I-C'),
#   (')', 'I-C'),
#   (',', 'I-C'),
#   ('a', 'I-C'),
#   ('State', 'I-C'),
#   ('Department-led', 'I-C'),
#   ('initiative', 'I-C'),
#   ('that', 'I-C'),
#   ('supports', 'I-C'),
#   ('women', 'I-C'),
#   ('entrepreneurs', 'I-C'),
#   ('around', 'I-C'),
#   ('the', 'I-C'),
#   ('world', 'I-C'),
#   ('.', 'E-C'),
#   ('During', 'B-E'),
#   ('a', 'I-E'),
#   ('week-long', 'I-E'),
#   ('program', 'I-E'),
#   (',', 'I-E'),
#   ('a', 'I-E'),
#   ('diverse', 'I-E'),
#   ('group', 'I-E'),
#   ('of', 'I-E'),
#   ('100', 'I-E'),
#   ('women', 'I-E'),
#   ('selected', 'I-E'),
#   ('from', 'I-E'),
#   ('a', 'I-E'),
#   ('pool', 'I-E'),
#   ('of', 'I-E'),
#   ('over', 'I-E'),
#   ('6,000', 'I-E'),
#   ('applicants', 'I-E'),
#   (',', 'I-E'),
#   ('will', 'I-E'),
#   ('receive', 'I-E'),
#   ('lessons', 'I-E'),
#   ('on', 'I-E'),
#   ('business', 'I-E'),
#   ('management', 'I-E'),
#   (',', 'I-E'),
#   ('network', 'I-E'),
#   ('with', 'I-E'),
#   ('like-minded', 'I-E'),
#   ('entrepreneurs', 'I-E'),
#   ('and', 'I-E'),
#   ('mentors', 'I-E'),
#   (',', 'I-E'),
#   ('and', 'I-E'),
#   ('learn', 'I-E'),
#   ('the', 'I-E'),
#   ('practical', 'I-E'),
#   ('skills', 'I-E'),
#   ('required', 'I-E'),
#   ('to', 'I-E'),
#   ('create', 'I-E'),
#   ('successful', 'I-E'),
#   ('and', 'I-E'),
#   ('sustainable', 'I-E'),
#   ('businesses', 'I-E'),
#   ('.', 'E-E')],
#  '0517.00003': [('NEW', 'B-C'),
#   ('DELHI', 'I-C'),
#   (':', 'I-C'),
#   ('With', 'I-C'),
#   ('a', 'I-C'),
#   ('lower', 'I-C'),
#   ('tax', 'I-C'),
#   ('rate', 'I-C'),
#   ('for', 'I-C'),
#   ('new', 'I-C'),
#   ('manufacturers', 'I-C'),
#   (',', 'I-C'),
#   ('the', 'I-C'),
#   ('government', 'I-C'),
#   ('is', 'I-C'),
#   ('looking', 'I-C'),
#   ('to', 'I-C'),
#   ('attract', 'I-C'),
#   ('investment', 'I-C'),
#   ('flowing', 'I-C'),
#   ('out', 'I-C'),
#   ('of', 'I-C'),
#   ('China', 'I-C'),
#   ('following', 'I-C'),
#   ('its', 'I-C'),
#   ('trade', 'I-C'),
#   ('dispute', 'I-C'),
#   ('with', 'I-C'),
#   ('the', 'I-C'),
#   ('US', 'I-C'),
#   (',', 'I-C'),
#   ('but', 'I-C'),
#   ('experts', 'I-C'),
#   ('say', 'I-C'),
#   ('India', 'I-C'),
#   ('needs', 'I-C'),
#   ('to', 'I-C'),
#   ('also', 'I-C'),
#   ('remove', 'I-C'),
#   ('other', 'I-C'),
#   ('major', 'I-C'),
#   ('obstacles', 'I-C'),
#   ('for', 'I-C'),
#   ('multinationals', 'I-C'),
#   ('to', 'I-C'),
#   ('consider', 'I-C'),
#   ('it', 'I-C'),
#   ('as', 'I-C'),
#   ('an', 'I-C'),
#   ('alternative', 'I-C'),
#   ('destination', 'I-C'),
#   ('to', 'I-C'),
#   ('the', 'I-C'),
#   ('neighbouring', 'I-C'),
#   ('country', 'I-C'),
#   ('.', 'E-C'),
#   ('The', 'B-E'),
#   ('15', 'I-E'),
#   ('%', 'I-E'),
#   ('rate', 'I-E'),
#   ('-', 'I-E'),
#   ('17', 'I-E'),
#   ('%', 'I-E'),
#   ('after', 'I-E'),
#   ('including', 'I-E'),
#   ('a', 'I-E'),
#   ('cess', 'I-E'),
#   ('and', 'I-E'),
#   ('surcharge', 'I-E'),
#   ('-', 'I-E'),
#   ('that', 'I-E'),
#   ('finance', 'I-E'),
#   ('minister', 'I-E'),
#   ('Nirmala', 'I-E'),
#   ('Sitharaman', 'I-E'),
#   ('announced', 'I-E'),
#   ('on', 'I-E'),
#   ('Friday', 'I-E'),
#   ('is', 'I-E'),
#   ('among', 'I-E'),
#   ('the', 'I-E'),
#   ('lowest', 'I-E'),
#   ('in', 'I-E'),
#   ('South', 'I-E'),
#   ('and', 'I-E'),
#   ('Southeast', 'I-E'),
#   ('Asia', 'I-E'),
#   ('.', 'E-E')],
#  '0517.00007': [('Bringing', 'B-E'),
#   ('down', 'I-E'),
#   ('the', 'I-E'),
#   ('corporate', 'I-E'),
#   ('tax', 'I-E'),
#   ('rate', 'I-E'),
#   ('to', 'I-E'),
#   ('15', 'I-E'),
#   ('%', 'I-E'),
#   ('for', 'I-E'),
#   ('new', 'I-E'),
#   ('manufacturing', 'I-E'),
#   ('is', 'I-E'),
#   ('a', 'I-E'),
#   ('deep', 'I-E'),
#   ('cut', 'I-E'),
#   ('.', 'E-E'),
#   ('In', 'B-C'),
#   ('the', 'I-C'),
#   ('medium', 'I-C'),
#   ('term', 'I-C'),
#   ('it', 'I-C'),
#   ('will', 'I-C'),
#   ('be', 'I-C'),
#   ('one', 'I-C'),
#   ('of', 'I-C'),
#   ('the', 'I-C'),
#   ('major', 'I-C'),
#   ('consideration', 'I-C'),
#   ('for', 'I-C'),
#   ('companies', 'I-C'),
#   ('to', 'I-C'),
#   ('shift', 'I-C'),
#   ('base', 'I-C'),
#   ('from', 'I-C'),
#   ('China', 'I-C'),
#   ('to', 'I-C'),
#   ('India', 'I-C'),
#   (',', 'I-C'),
#   ('said', 'I-C'),
#   ('DK', 'I-C'),
#   ('Joshi', 'I-C'),
#   (',', 'I-C'),
#   ('principal', 'I-C'),
#   ('economist', 'I-C'),
#   ('at', 'I-C'),
#   ('Crisil', 'I-C'),
#   ('.', 'E-C')],
#  '0517.00012': [('Finance', 'B-E'),
#   ('minister', 'I-E'),
#   ('Sitharaman', 'I-E'),
#   ('said', 'I-E'),
#   ('the', 'I-E'),
#   ('government', 'I-E'),
#   ('would', 'I-E'),
#   ('allow', 'I-E'),
#   ('any', 'I-E'),
#   ('new', 'I-E'),
#   ('domestic', 'I-E'),
#   ('company', 'I-E'),
#   ('incorporated', 'I-E'),
#   ('on', 'I-E'),
#   ('or', 'I-E'),
#   ('after', 'I-E'),
#   ('October', 'I-E'),
#   ('1', 'I-E'),
#   (',', 'I-E'),
#   ('2019', 'I-E'),
#   ('and', 'I-E'),
#   ('making', 'I-E'),
#   ('fresh', 'I-E'),
#   ('investment', 'I-E'),
#   ('in', 'I-E'),
#   ('manufacturing', 'I-E'),
#   ('to', 'I-E'),
#   ('pay', 'I-E'),
#   ('income', 'I-E'),
#   ('tax', 'I-E'),
#   ('at', 'I-E'),
#   ('15', 'I-E'),
#   ('%', 'I-E'),
#   ('as', 'I-E'),
#   ('well', 'I-E'),
#   ('as', 'I-E'),
#   ('exemptions', 'I-E'),
#   ('from', 'I-E'),
#   ('the', 'I-E'),
#   ('minimum', 'I-E'),
#   ('alternate', 'I-E'),
#   ('tax', 'I-E'),
#   (',', 'E-E'),
#   ('provided', 'S-M'),
#   ('it', 'B-C'),
#   ('did', 'I-C'),
#   ('not', 'I-C'),
#   ('avail', 'I-C'),
#   ('of', 'I-C'),
#   ('any', 'I-C'),
#   ('exemption', 'I-C'),
#   ('or', 'I-C'),
#   ('incentive', 'I-C'),
#   ('and', 'I-C'),
#   ('commences', 'I-C'),
#   ('production', 'I-C'),
#   ('by', 'I-C'),
#   ('March', 'I-C'),
#   ('31', 'I-C'),
#   (',', 'I-C'),
#   ('2023', 'I-C'),
#   ('.', 'E-C')],
#  '0517.00013': [('Adding', 'B-C'),
#   ('the', 'I-C'),
#   ('cess', 'I-C'),
#   ('and', 'I-C'),
#   ('surcharge', 'I-C'),
#   (',', 'E-C'),
#   ('the', 'B-E'),
#   ('effective', 'I-E'),
#   ('tax', 'I-E'),
#   ('rate', 'I-E'),
#   ('for', 'I-E'),
#   ('these', 'I-E'),
#   ('companies', 'I-E'),
#   ('will', 'I-E'),
#   ('be', 'I-E'),
#   ('17.01', 'I-E'),
#   ('%', 'I-E'),
#   ('.', 'E-E')],
#  '0523.00006.1': [('As', 'B-E'),
#   ('for', 'I-E'),
#   ('their', 'I-E'),
#   ('separate', 'I-E'),
#   ('arguments', 'I-E'),
#   (',', 'I-E'),
#   ('Fraser-Jenkins', 'I-E'),
#   ('says', 'I-E'),
#   ('there', 'I-E'),
#   ('are', 'I-E'),
#   ('plenty', 'I-E'),
#   ('of', 'I-E'),
#   ('reasons', 'I-E'),
#   ('that', 'I-E'),
#   ('the', 'I-E'),
#   ('S', 'I-E'),
#   ('&', 'I-E'),
#   ('P', 'I-E'),
#   ('ca', 'I-E'),
#   ("n't", 'I-E'),
#   ('go', 'I-E'),
#   ('higher', 'I-E'),
#   ('than', 'I-E'),
#   ('4,000', 'I-E'),
#   ('.', 'E-E'),
#   ('Chiefly', 'B-C'),
#   (',', 'I-C'),
#   ('he', 'I-C'),
#   ('points', 'I-C'),
#   ('to', 'I-C'),
#   ('evidence', 'I-C'),
#   ('that', 'I-C'),
#   ('equities', 'I-C'),
#   ('are', 'I-C'),
#   ('expensive', 'I-C'),
#   ('using', 'I-C'),
#   ('the', 'I-C'),
#   ('Shiller', 'I-C'),
#   ('cyclically', 'I-C'),
#   ('adjusted', 'I-C'),
#   ('price-to-earnings', 'I-C'),
#   ('ratio', 'I-C'),
#   ('(', 'I-C'),
#   ('a', 'I-C'),
#   ('popular', 'I-C'),
#   ('stock-valuation', 'I-C'),
#   ('measure', 'I-C'),
#   (')', 'I-C'),
#   ('.', 'E-C'),
#   ('Also', 'B-A'),
#   (',', 'I-A'),
#   ('low', 'I-A'),
#   ('yields', 'I-A'),
#   ('and', 'I-A'),
#   ('baby', 'I-A'),
#   ('boomers', 'I-A'),
#   ('pouring', 'I-A'),
#   ('money', 'I-A'),
#   ('into', 'I-A'),
#   ('stocks', 'I-A'),
#   ('have', 'I-A'),
#   ('helped', 'I-A'),
#   ('keep', 'I-A'),
#   ('the', 'I-A'),
#   ('S', 'I-A'),
#   ('&', 'I-A'),
#   ('P', 'I-A'),
#   ('moving', 'I-A'),
#   ('up', 'I-A'),
#   (',', 'I-A'),
#   ('and', 'I-A'),
#   ('household', 'I-A'),
#   ('equity', 'I-A'),
#   ('allocation', 'I-A'),
#   ('is', 'I-A'),
#   ('at', 'I-A'),
#   ('an', 'I-A'),
#   ('all-time', 'I-A'),
#   ('high', 'I-A'),
#   (',', 'I-A'),
#   ('he', 'I-A'),
#   ('says', 'I-A'),
#   ('.', 'E-A')],
#  '0523.00006.2': [('As', 'B-E'),
#   ('for', 'I-E'),
#   ('their', 'I-E'),
#   ('separate', 'I-E'),
#   ('arguments', 'I-E'),
#   (',', 'I-E'),
#   ('Fraser-Jenkins', 'I-E'),
#   ('says', 'I-E'),
#   ('there', 'I-E'),
#   ('are', 'I-E'),
#   ('plenty', 'I-E'),
#   ('of', 'I-E'),
#   ('reasons', 'I-E'),
#   ('that', 'I-E'),
#   ('the', 'I-E'),
#   ('S', 'I-E'),
#   ('&', 'I-E'),
#   ('P', 'I-E'),
#   ('ca', 'I-E'),
#   ("n't", 'I-E'),
#   ('go', 'I-E'),
#   ('higher', 'I-E'),
#   ('than', 'I-E'),
#   ('4,000', 'I-E'),
#   ('.', 'E-E'),
#   ('Chiefly', 'B-M'),
#   (',', 'I-M'),
#   ('he', 'I-M'),
#   ('points', 'I-M'),
#   ('to', 'I-M'),
#   ('evidence', 'I-M'),
#   ('that', 'I-M'),
#   ('equities', 'I-M'),
#   ('are', 'I-M'),
#   ('expensive', 'I-M'),
#   ('using', 'I-M'),
#   ('the', 'I-M'),
#   ('Shiller', 'I-M'),
#   ('cyclically', 'I-M'),
#   ('adjusted', 'I-M'),
#   ('price-to-earnings', 'I-M'),
#   ('ratio', 'I-M'),
#   ('(', 'I-M'),
#   ('a', 'I-M'),
#   ('popular', 'I-M'),
#   ('stock-valuation', 'I-M'),
#   ('measure', 'I-M'),
#   (')', 'I-M'),
#   ('.', 'E-M'),
#   ('Also', 'B-C'),
#   (',', 'I-C'),
#   ('low', 'I-C'),
#   ('yields', 'I-C'),
#   ('and', 'I-C'),
#   ('baby', 'I-C'),
#   ('boomers', 'I-C'),
#   ('pouring', 'I-C'),
#   ('money', 'I-C'),
#   ('into', 'I-C'),
#   ('stocks', 'I-C'),
#   ('have', 'I-C'),
#   ('helped', 'I-C'),
#   ('keep', 'I-C'),
#   ('the', 'I-C'),
#   ('S', 'I-C'),
#   ('&', 'I-C'),
#   ('P', 'I-C'),
#   ('moving', 'I-C'),
#   ('up', 'I-C'),
#   (',', 'I-C'),
#   ('and', 'I-C'),
#   ('household', 'I-C'),
#   ('equity', 'I-C'),
#   ('allocation', 'I-C'),
#   ('is', 'I-C'),
#   ('at', 'I-C'),
#   ('an', 'I-C'),
#   ('all-time', 'I-C'),
#   ('high', 'I-C'),
#   (',', 'I-C'),
#   ('he', 'I-C'),
#   ('says', 'I-C'),
#   ('.', 'E-C')],
#  '0523.00008': [('Even', 'B-C'),
#   ('if', 'I-C'),
#   ('households', 'I-C'),
#   ('do', 'I-C'),
#   ("n't", 'I-C'),
#   ('keep', 'I-C'),
#   ('buying', 'I-C'),
#   ('stocks', 'I-C'),
#   (',', 'E-C'),
#   ('there', 'B-E'),
#   ("'s", 'I-E'),
#   ('plenty', 'I-E'),
#   ('of', 'I-E'),
#   ('proof', 'I-E'),
#   ('companies', 'I-E'),
#   ('will', 'I-E'),
#   ('keep', 'I-E'),
#   ('buying', 'I-E'),
#   ('back', 'I-E'),
#   ('their', 'I-E'),
#   ('own', 'I-E'),
#   ('shares', 'I-E'),
#   (',', 'I-E'),
#   ('with', 'I-E'),
#   ('some', 'I-E'),
#   ('$', 'I-E'),
#   ('820', 'I-E'),
#   ('billion', 'I-E'),
#   ('in', 'I-E'),
#   ('buybacks', 'I-E'),
#   ('announced', 'I-E'),
#   ('this', 'I-E'),
#   ('year', 'I-E'),
#   ('alone', 'I-E'),
#   (',', 'I-E'),
#   ('said', 'I-E'),
#   ('Harmsworth', 'I-E'),
#   ('.', 'E-E')],
#  '0523.00012': [('Oil', 'B-E'),
#   ('CLV19', 'I-E'),
#   (',', 'I-E'),
#   ('+0.88', 'I-E'),
#   ('%', 'I-E'),
#   ('is', 'I-E'),
#   ('up', 'E-E'),
#   ('as', 'S-M'),
#   ('an', 'B-C'),
#   ('Iranian', 'I-C'),
#   ('diplomat', 'I-C'),
#   ('in', 'I-C'),
#   ('case', 'I-C'),
#   ('of', 'I-C'),
#   ('an', 'I-C'),
#   ('attack', 'I-C'),
#   ('over', 'I-C'),
#   ('the', 'I-C'),
#   ('weekend', 'I-C'),
#   ('Saudi', 'I-C'),
#   ('drone', 'I-C'),
#   ('strike', 'I-C'),
#   ('.', 'E-C')],
#  '0523.00018': [('Retailer', 'B-E'),
#   ('Target', 'I-E'),
#   ('TGT', 'I-E'),
#   (',', 'I-E'),
#   ('+0.13', 'I-E'),
#   ('%', 'I-E'),
#   ('is', 'I-E'),
#   ('up', 'E-E'),
#   ('on', 'S-M'),
#   ('news', 'B-C'),
#   ('of', 'I-C'),
#   ('a', 'I-C'),
#   ('After', 'I-C'),
#   ('a', 'I-C'),
#   ('dramatic', 'I-C'),
#   ('exit', 'I-C'),
#   ('as', 'I-C'),
#   ('CEO', 'I-C'),
#   ('of', 'I-C'),
#   ('Overstock', 'I-C'),
#   (',', 'I-C'),
#   ('Patrick', 'I-C'),
#   ('Byrne', 'I-C'),
#   (',', 'I-C'),
#   ('blaming', 'I-C'),
#   ('the', 'I-C'),
#   ('Securities', 'I-C'),
#   ('and', 'I-C'),
#   ('Exchange', 'I-C'),
#   ('Commission', 'I-C'),
#   (',', 'I-C'),
#   ('or', 'I-C'),
#   (',', 'I-C'),
#   ('as', 'I-C'),
#   ('he', 'I-C'),
#   ('now', 'I-C'),
#   ('calls', 'I-C'),
#   ('the', 'I-C'),
#   ('regulator', 'I-C'),
#   (',', 'I-C'),
#   ('the', 'I-C'),
#   ('Deep', 'I-C'),
#   ('State', 'I-C'),
#   ("'s", 'I-C'),
#   ('pets', 'I-C'),
#   ('.', 'E-C')],
#  ...}

# %% [markdown]
# # Convert for Thesis code

# %%
def convert(out_folder: str, cebam: bool=True):
    sentences_file = os.path.join(out_folder, 'sentences.txt')
    labels_file = os.path.join(out_folder, 'labels.txt')
    id_file = os.path.join(out_folder, 'ID.txt')
    with open(sentences_file, 'w') as s_f, open(labels_file, 'w') as l_f, open(id_file, 'w') as i_f:
        for uid, tokens_with_labels in list_of_texts_tokenized_and_labeled.items():
            labels = [t[1] for t in tokens_with_labels]
            tokens = [t[0] for t in tokens_with_labels]
            if not cebam:
                labels = [l if l.split('-')[1]=='C' or l.split('-')[1]=='E' else 'O' for l in labels]
            assert len(tokens) == len(labels)
            sentence_str = " ".join(str(t) for t in tokens)
            label_str = " ".join(l for l in labels)
            id_str = uid
            i_f.write(id_str)
            s_f.write(sentence_str)
            l_f.write(label_str)
            
            i_f.write('\n')
            s_f.write('\n')
            l_f.write('\n')

# %%
convert('/media/sarthak/HDD/TUM/Thesis/thesis-sarthak/src/ner/datasets/fincausal_task2v2_iobes_CEBAM/test', cebam=True)

# %%
convert('/media/sarthak/HDD/TUM/Thesis/thesis-sarthak/src/ner/datasets/fincausal_task2v2_iobes_CEO/test', cebam=False)

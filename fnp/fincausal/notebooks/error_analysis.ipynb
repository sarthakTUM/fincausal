# %%
import pandas as pd
from pathlib import Path

# %%
predictions_filepath = Path('//media/sarthak/HDD/data_science/fnp_resources/fincausal_t1_models/51_1/output/best_model/inference/predictions.csv')
# predictions_9_iteration_1_path = Path('/media/sarthak/HDD/data_science/fnp_resources/fincausal_t1_models/9/iteration_1/output/best_model/inference/predictions.csv')

# %%
predictions = pd.read_csv(predictions_filepath)
# predictions_9_iteration_1 = pd.read_csv(predictions_9_iteration_1_path)

# %%
predictions.head()
# Out:
#        Index                                               Text  Gold  \
# 0  352.00039  One bit of advice Orton had for young finance ...     0
# 1    8.00001  President Muhammadu Buhari has disclosed that ...     1
# 2   53.00010  Advent of compressed exhaust systems based on ...     0
# 3  533.00022  Catholic leaders have also suggested the UK go...     0
# 4  316.00040  (NasdaqGS:CME) is 66. A company with a value o...     0
#
#    Prediction                             unique_id
# 0           0  f56182ea-5095-4934-889c-f18c1a26134c
# 1           1  06cc12f1-1df2-43ef-898a-85ebb29bdede
# 2           0  a2705c77-271b-4870-b948-8b688657f39c
# 3           0  7966c427-9695-4e2f-a098-a5d385d6e0c4
# 4           0  14e3e218-9f6b-4949-96c7-62ca68598d55

# %%
# locate errors
errors = predictions.loc[predictions.Gold != predictions.Prediction].reset_index()
errors.head()
# Out:
#    index      Index                                               Text  Gold  \
# 0     17  544.00031  This is:- 1. IRP and liquidation costs 2. Work...     0
# 1     47  403.00009  The San Antonio Economic Development Foundatio...     0
# 2     59  323.00098  High street stalwart Next reported a rise in p...     0
# 3    103   21.00003  More than half of the property is rented on th...     0
# 4    108  171.00035  For those retiring early, at age 62, the maxim...     1
#
#    Prediction                             unique_id
# 0           1  203c03f1-1db1-4671-8b81-f94442679134
# 1           1  16516ba0-710a-4cf1-b5d5-3a24f9593962
# 2           1  b649f39f-c262-4c5e-9a71-562289589bf2
# 3           1  cd20eb77-16f7-4868-a098-925c6bac5340
# 4           0  acde9d96-2fb4-4bf3-97c9-38dbd0c804f3

# %%
random_idx = 20

# %%
errors.iloc[random_idx].Text, errors.iloc[random_idx].Gold, errors.iloc[random_idx].Prediction, errors.iloc[random_idx].Index
# Out:
# ("This was later confirmed, with Saudi's oil minister saying that just under half of lost oil production has returned to the market and production will be 11m barrels per day by the end of September, its pre-attack level.",
#  0,
#  1,
#  249.00006000000002)

# %%
# try dependency parsing
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(errors.iloc[random_idx].Text)

# %%
displacy.render(doc, style="dep", jupyter=True, options={'distance':140})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b5be9fb9b04a4fd69733aff8637891c4-0" class="displacy" width="8730" height="627.0" direction="ltr" style="max-width: none; height: 627.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="190">promptly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="190">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="330">told</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="330">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="470">Son:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="610">Today,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">'m</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1030">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1030">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1170">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1170">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">negotiator,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">signed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="1870">name,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1870">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2010">plus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2010">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Son</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2290">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2290">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2430">name,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2430">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">thereby</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2710">sealing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2710">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="2990">investment</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2990">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">deal.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3270">Wired</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">added</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3690">deal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3830">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3830">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="3970">agreed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3970">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="4110">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4110">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="537.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">both</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <tex
